# %%
from progress.bar import IncrementalBar

#file = open('FocusObj.txt', 'r', encoding='866')
file = open('DFObjects.txt', 'r', encoding='866')
#file = open('20241227_082640_EKTP.txt', 'r', encoding='866')
fileOut = open('output.txt', 'w', encoding='1251')
#fileOutXml = 'output.xml'
fileOutXml = ''


lineNo = 0
#parentLineNo = 0;
propLine = []; #id, parentId, lineType, propName, propType, propValue, lineNo, startPos, addInfo
propTable = []
levelBuffer = []  #lineNo, indentPos, proprtyType, propertyName
bSkipObject = False
currSection = ''
propName = ''
propType = ""
propValue = ''
lineType = ''
propLineNo = 0
valIndent = 0

def FSym(s):
  if len(s)==0:
    return '',-1
  s2 = s.lstrip()
  c = s2[0]
  pos = s.find(c)
  return c, pos

def FWord(str):
  s = str.lstrip()
  pos = s.find("=", 0)
  if pos > 0:
    sep = '='
    word = s[:pos]
    tail2 = s[pos+1:]
    return word, tail2, sep  
  pos = s.find(" : ", 0)
  if pos > 0:
    sep = ':'
    word = s[:pos]
    tail2 = s[pos+3:]
    return word, tail2, sep
  pos = s.find(" ", 0)
  if pos > 0:
    sep = ' '
    word = s[:pos]
    tail2 = s[pos+1:]
    return word, tail2, sep
  return s, '', ''
   
def AddProperty(*args):  #StartProperty2
  lineNo = args[0]
  #Позиция, с которой начинается
  startPos = args[1]
  #Свойство propName+propValue (обрезанная строка)
  propString = args[2]  
  propType = ''  
  #retValue
  global levelBuffer
  global propTable  
  global valIndent    
  global lineType
  global propLineNo

  propLineNo += 1
  #levelBuffer = setLevel(levelBuffer, lineNo, startPos)
  if lineType == 'documentation':
    startPos = 4
  levelBuffer = setLevel(levelBuffer, propLineNo, startPos)
  parent = levelBuffer[len(levelBuffer)-2]

  if lineType == 'cal':
    propName = ''
    propValue = propString
    #propLine = [lineNo, parent[0] , lineType, propName, propValue, startPos];
    propLine = [propLineNo, parent[0] , lineType, propName, '', propValue, lineNo, startPos]
    propTable.append(propLine)
    return propLine
  if lineType == 'var':
    word, tail, sep = FWord(propString)
    #propName = word
    p = word.find("@",0) 
    propName = word[:p]
    propValue = tail.lstrip().rstrip(';}')    
    #propLine = [lineNo, parent[0] , lineType, propName, propValue, startPos];
    propType, propValue, addInfo = GetTypeAndValue(propValue)
    propLine = [propLineNo, parent[0] , lineType, propName, propType, propValue, lineNo, startPos, addInfo]
    propTable.append(propLine)
    return propLine
  if lineType == 'documentation':
    propName = ''
    propValue = propString    
    propLine = [propLineNo, parent[0] , 'documentation', propName, '', propValue, lineNo, startPos+2]
    propTable.append(propLine)
    return propLine
  
  word, tail, sep = FWord(propString)
  propName = word
  #VNR261224  propValue = tail.rstrip(';} ')  
  propValue = tail.rstrip('} ')  
  #lineNo, indentPos, proprtyType, propertyName
  
  if propValue=="BEGIN":
    #propLine = [lineNo, parent[0] , 'trigger', propName, '', startPos];
    propLine = [propLineNo, parent[0] , 'trigger', propName, '', '', lineNo, startPos]
    propTable.append(propLine)    
    valIndent = startPos+propString.find("BEGIN", 0)     
    lineType = 'cal'
    return propLine
  if propValue=="VAR":
    #propLine = [lineNo, parent[0] , 'trigger', propName, '', startPos];    
    propLine = [propLineNo, parent[0] , 'trigger', propName, '', '', lineNo, startPos]
    propTable.append(propLine)    
    valIndent = startPos+propString.find("VAR", 0)    
    lineType = 'var'
    return propLine  
  #propLine = [propLineNo, parent[0] , 'property', propName, "", propValue, lineNo, startPos]
  propType, propValue, addInfo = GetTypeAndValue(propValue)
  propLine = [propLineNo, parent[0], 'property', propName, propType, propValue, lineNo, startPos, addInfo]
  valIndent = startPos+propString.find(propValue, 0)
  propTable.append(propLine)

  return propLine

  
def StartProcedure(*args):
  lineNo = args[0]
  #Позиция, с которой начинается
  startPos = args[1]
  #Свойство propName+propValue (обрезанная строка)
  propString = args[2]  
  propType = ''  
  #global procMode
  global lineType
  global propLineNo
  global levelBuffer
  global propTable
  propString = propString.lstrip()
  pos = propString.find(" ", 0)
  if pos == 0:
    return      
  word = propString[:pos]
  if not word in ["LOCAL","PROCEDURE"]:
    return
  #procMode = True
  lineType = 'procedure'
  #propName = 'Procedure' 
  i0 = propString.find('PROCEDURE')+10
  i1 = propString.find('@')
  #propValue = propString[i0:i1]
  propName = propString[i0:i1]
  propValue = ""

  propLineNo += 1
  #levelBuffer = setLevel(levelBuffer, lineNo, startPos)
  levelBuffer = setLevel(levelBuffer, propLineNo, startPos)
  parent = levelBuffer[len(levelBuffer)-2]
  #propLine = [lineNo, parent[0] , lineType, propName, propValue, startPos];
  propLine = [propLineNo, parent[0] , lineType, propName, "", propValue, lineNo, startPos]
  propTable.append(propLine) 

  i0 = propString.find('(')+1
  #i1 = propString.find(')')
  i1 = propString.rindex(")")
  procParams =  propString[i0:i1]
  if procParams != '':
    #levelBuffer = setLevel(levelBuffer, lineNo, startPos)
    #propLineNo += 1
    #levelBuffer = setLevel(levelBuffer, propLineNo, startPos)
    parent = levelBuffer[len(levelBuffer)-1]
    procParams = procParams.split(';')
    for param in procParams:
      addInfo = ""
      param = param.split(':')
      propName = param[0].split('@')[0]
      propValue = param[1].lstrip()
      #propLine = [lineNo, parent[0] , 'param', propName, propValue, startPos]
      propType, propValue, addInfo = GetTypeAndValue(propValue)
      if propName[:3]=="VAR":
         addInfo = "var"
         propName = propName[4:]
      propLineNo += 1
      propLine = [propLineNo, parent[0] , 'param', propName, propType, propValue, lineNo, startPos, addInfo]
      propTable.append(propLine) 
  
def AddValue(line):
  global propTable
  propTable[len(propTable)-1][5] += line.rstrip(';}')  
  return;

def setLevel(*args):
    global valIndent
    buffer = args[0]
    lineNo = args[1]
    posNo = args[2]
    '''
    lastPosNo = 0
    if len(buffer)>=1:
      lastPosNo = buffer[len(buffer)-1][1]
    if posNo < lastPosNo:
      valIndent = 0
    '''  
    pType = ''
    if len(args)>3:
      pType = args[3]
    pName = ''
    if len(args)>4:
      pName = args[4]
    newBuffer = []
    for item in buffer:
        #line, indent, level
        if item[1] < posNo:
          newBuffer.append(item)        
        elif item[1] >= posNo:
            newBuffer.append([lineNo, posNo, pType, pName])            
            return newBuffer    
    newBuffer.append([lineNo, posNo, pType, pName])
    return newBuffer

def GetTypeAndValue(line):
  propType = ""  
  propValue = line
  addInfo = ""
  if propValue[:8] == "Codeunit":
    propType = propValue[:8]
    propValue = propValue[8:].lstrip(" [")
  elif propValue[:4] in ["Text","Code","Form"]:
    propType = propValue[:4]
    propValue = propValue[4:].lstrip(" [").rstrip("] ")
  elif propValue[:6]=="Record" and propValue[:9]!="RecordRef":
    propType = "Record"
    propValue = propValue[7:]
  elif propValue.find("TEMPORARY Record",0)==0:
    propType = "Record"
    propValue = propValue[17:]
    addInfo = "tmp"    
  elif propValue.find("Automation",0)==0:
    propType = "Automation"
    propValue = propValue[propValue.find("}:")+2:].rstrip('"')
  return propType, propValue, addInfo





bHasError = False
str1 = ""
for ln in file:
  lineNo += 1
  if ln.find('\t')>=0:
    print('Строка '+str(lineNo)+': Знак табуляции')
    bHasError = True
  try:  
    str1 = ln.encode("866")  #1251 - any, ascii - all, 866- no
    str1 = ln.encode("1251")  #fileOut
  except Exception:
    print('Строка '+str(lineNo)+': Косяк: '+ln)
    bHasError = True

if bHasError:
  quit()

print("Обработка файла "+file.name);

totalLines = lineNo
lineNo = 0
file.seek(0)
line = file.readline()

bar = IncrementalBar('Обработка ', max = totalLines)
propLine = [propLineNo, 0, 'root', 'objName', 'objType', 'objNo', 'lineNo', 0]    
propTable.append(propLine)

while line:
  #bSkipObject = True
  lineNo += 1  
  bar.next();  
  
  line = line.rstrip()  
  #print(line)
  if len(line.lstrip().rstrip()) == 0:
    line = file.readline()
    continue  
  lineShort = line.lstrip().rstrip()
  if lineShort in ['{','}']:
    if lineType != "cal":
      line = file.readline()
      continue 
  if lineShort.find('{ PROPERTIES')>=0:  
      line = line.replace('{',' ')
      lineShort = lineShort.replace('{',' ')
      lineShort = line.lstrip()

  #OBJECT
  sym, pos = FSym(line); 
  if pos==0:  #Object       
    s = line.lstrip().split(' ')
    objType = s[1]
    objNo = s[2]
    objName = " ".join(s[3:])
  #if (objType == 'Table') and (int(objNo) in range(1,23)):
  #if objType in ['Table','Form','Report','Codeunit'] and int(objNo)==69:  # in range(1,4)):
  #  bSkipObject = False    
  if bSkipObject:  #or (currSection in ['KEYS','FIELDGROUPS']):
    line = file.readline()
    continue
  if pos==0:  #Object
    #levelBuffer = setLevel(levelBuffer, lineNo, 0, 'object', objNo)
    propLineNo += 1
    levelBuffer = setLevel(levelBuffer, propLineNo, 0, 'object', objNo)
    propLine = [propLineNo, 0, 'object', objName, objType, objNo, lineNo, 0]
    propTable.append(propLine)
    line = file.readline()
    continue

  #SECTION
  if lineShort == lineShort.upper():
    sectionLine = False
    if pos in [2,4]:
      if lineShort not in ['VAR','BEGIN','END;','END.']:
        sectionLine = True
    if pos in [6,8,10,12,14]:
      if lineShort in ['PROPERTIES','CONTROLS','SECTIONS']:
        sectionLine = True
    if sectionLine:
      currSection = lineShort
      #levelBuffer = setLevel(levelBuffer, lineNo, pos, 'section', currSection)
      propLineNo += 1
      levelBuffer = setLevel(levelBuffer, propLineNo, pos, 'section', currSection)
      parent = levelBuffer[len(levelBuffer)-2][0]
      #propLine = [lineNo, parent , 'section', currSection, '', pos]
      propLine = [propLineNo, parent , 'section', currSection, '', '', lineNo, pos]
      propTable.append(propLine)
      '''
      propIndent = pos+2         #Property
      prop2Indent = 0
      if currSection == 'FIELDS':        
        prop2Indent = 51      #Property2
      '''
      valIndent = 0
      lineType = ''
      line = file.readline()
      continue

    
  #PROPERTY      
  #if lineNo == 17: #6653:
  #  print("stop")
  #if lineNo == 923: #6653:
  #  print("break")
  #  break
      
  if pos>=4:
    #starting CAL block after VAR block (procedure/trigger)
    if pos==valIndent and lineType=='var' and lineShort == "BEGIN":      
      lineType='cal'
      line = file.readline()
      continue
    #ending VAR block (procedure/trigger), ending CAL block (procedure), ending procedure body
    if pos==valIndent and lineType!='' and lineShort == "END;":
      valIndent = 0
      lineType=''
      line = file.readline()
      continue
    #!!!! documentation !!!!
    if pos==valIndent+2 and lineType=='':
      #AddValue()
      propTable[len(propTable)-1][4]+=lineShort
      line = file.readline()
      continue
    #property: variable block (in code/procedure/trigger)
    if pos==valIndent+2 and lineType=='var':
      AddProperty(lineNo, valIndent+2, line[pos:])
      line = file.readline()
      continue
    #continues CAL code in procedure
    if pos>=valIndent+2 and lineType=='cal':
      AddProperty(lineNo, valIndent+2, line[valIndent+2:])   
      line = file.readline()
      continue
    #reset value indentation
    if pos<valIndent:
      valIndent = 0
    #adding of multiline property  
    if valIndent>0 and pos>=valIndent and lineType=='':  #+ end of documentation 170,303      
      AddValue(line[pos-1:])
      line = file.readline()
      continue
        
  #if pos>=4:
    if sym=='{' and currSection == 'FIELDS':       
      valIndent = 0
      s = lineShort.split(';')
      propNumber =  int(s[0].lstrip("{ ").rstrip())
      propName = s[2].rstrip()
      propValue = s[3].rstrip(' }')  #Text20
      if propValue[:4] in ["Text","Code"]:
        propType = propValue[:4]
        propValue = propValue[4:]
      else:
        propType = propValue
        propValue = ""
      #levelBuffer = setLevel(levelBuffer, lineNo, pos, 'field', propName)
      propLineNo += 1
      levelBuffer = setLevel(levelBuffer, propLineNo, pos, 'field', propName)
      parent = levelBuffer[len(levelBuffer)-2]
      #propLine = [lineNo, parent[0] , 'field', propName, propValue, pos];
      propLine = [propLineNo, parent[0] , 'field', propName, propType, propValue, lineNo, pos]  #, propNumber]
      propTable.append(propLine)
      if len(s)>=5:
        if len(s[4])>0:          
          #StartProperty(s[4])
          AddProperty(lineNo, line.find(s[4]), s[4])
      line = file.readline()
      continue
    
    if sym=='{' and currSection == 'CONTROLS':
      valIndent = 0      
      s = lineShort.split(';')
      propName = 'Control'+s[0][2:].rstrip()
      propValue = s[1].rstrip('} ')
      #levelBuffer = setLevel(levelBuffer, lineNo, pos, 'control', propName)
      propLineNo += 1
      levelBuffer = setLevel(levelBuffer, propLineNo, pos, 'control', propName)
      parent = levelBuffer[len(levelBuffer)-2]
      #propLine = [lineNo, parent[0] , 'control', propName, propValue, pos];
      propLine = [propLineNo, parent[0] , 'control', propName, "", propValue, lineNo, pos]
      propTable.append(propLine)
      if len(s)>=7:
        if len(s[6])>0:
          AddProperty(lineNo, line.find(s[6]), s[6])
      line = file.readline()
      continue
        
    if sym=='{' and currSection == 'KEYS':
      valIndent = 0
      s = lineShort.split(';')
      propName = 'Key';
      propValue = s[1].rstrip(' ;}')
      propLineNo += 1
      levelBuffer = setLevel(levelBuffer, propLineNo, pos, 'key', propName)
      parent = levelBuffer[len(levelBuffer)-2]
      propLine = [propLineNo, parent[0] , 'key', propName, "", propValue, lineNo, pos]
      propTable.append(propLine)
      if len(s)>=3:
        if len(s[2])>0:
          AddProperty(lineNo, line.find(s[2]), s[2])
      line = file.readline()
      continue    
        
  #if pos>=4:
    if currSection == "CODE":
      #starts VAR block in code section
      if lineShort == "VAR" and lineType=='':   
        lineType = 'var'
        valIndent = pos
        line = file.readline()
        continue
      #starts VAR block in procedure body
      if lineShort == "VAR" and lineType=='procedure':
        lineType = 'var'    
        valIndent = pos
        line = file.readline()
        continue
      #starts CAL block in procedure body
      if lineShort == "BEGIN" and lineType in ['procedure','var']:
        lineType = 'cal'    
        valIndent = pos
        line = file.readline()
        continue
      #usage is undetected
      if lineShort == "END;" and lineType in ['var','cal']:   
        lineType = ''
        line = file.readline()
        continue
      #starting procedure header  
      if pos==4 and sym in ['L','P']: # and lineType=='':
        word = ""   
        pos2 = lineShort.find(" ", 0)
        if pos2 > 0:
          word = lineShort[:pos2]
        if word in ["LOCAL","PROCEDURE"]:
          StartProcedure(lineNo, pos, lineShort)  
          line = file.readline()
          continue
      #starting documentation block 
      if pos==4 and lineType=='' and lineShort == "BEGIN":
        lineType = 'documentation'
        #propLineNo += 1
        #levelBuffer = setLevel(levelBuffer, propLineNo, pos, 'documentation', currSection)
        line = file.readline()
        continue      
      #ending documentation block 
      if pos==4 and lineType=='documentation' and lineShort == "END.":
        lineType = ''
        line = file.readline()
        continue

      '''  
      if lineShort == "VAR":
        if procMode:
          StartProperty('Procedure=VAR')
        else:  
          StartProperty('Object=VAR')
      if lineShort == "BEGIN":
        StartProperty('Procedure=BEGIN')
      if lineShort == "END;":
        EndValue()
        procMode = False
      '''
      AddProperty(lineNo, pos, lineShort)
      line = file.readline()
      continue
    #end of CODE

    #ordinary property: name=value/name:value
    AddProperty(lineNo, pos, lineShort)
    line = file.readline()
    continue

  #if pos>=4:

  line = file.readline()

file.close()
bar.finish()

print("Выгрузка файла "+fileOut.name);
bar = IncrementalBar('Выгрузка', max = len(propTable))
for line in propTable:
  #print(line)
  fileOut.write(str(line)+"\n")  
  bar.next()
fileOut.close()  
bar.finish()



if (fileOutXml != ''):      
    bar = IncrementalBar('Экспорт XML', max = len(propTable))
    import xml.etree.ElementTree as xml
    root = xml.Element("root")
    el = []
    el.append(0)
    lastId = -1
    lineId = -1
    finalId = len(propTable)-1
    for line in propTable:
      bar.next()
      lineId += 1
      el.append(line)
      lastId += 1  
      
      if line[1] == 0:
        parent = root
      else:
        parent = el[line[1]]
      #если еcть подчиненный элемент то делаешь простой с аттрибутами
      #appt = xml.Element("appointment")
      #appt.attrib = {"attrib":"value"}
      #root.append(appt)   
      if lineId < finalId and propTable[lineId+1][1] == line[0]:  
        el[line[0]] = xml.Element(line[2])
        attr = {}
        #[propLineNo, parent[0] , 'field', propName, propType, propValue, lineNo, pos, propNumber]
        if line[3]!='':
          attr.update({"name":line[3]})
        if line[4]!='':
          attr.update({"type":line[4]})
        if line[5]!='':
          attr.update({"value":line[5]})
        #if len(line) >= 9:
        #  attr.update({"no":line[8]})
        el[line[0]].attrib = attr
        parent.append(el[line[0]]) 
      else:
        el[line[0]] = xml.SubElement(parent, line[2])
        #el[line[0]].text = "value"  
        #el[line[0]].text = "Name="+line[3]+" Type="+line[4]+" Value="+line[5]
        #if len(line) >= 9:
        #  line[3] += " ("+str(line[8])+")"
        if line[3]=="":
          el[line[0]].text = line[5]
        elif line[4]!="":
          el[line[0]].text = line[3]+"="+line[4]+"("+line[5]+")"
        else:  
          el[line[0]].text = line[3]+"="+line[5]
    #xml.dump(root)
    tree = xml.ElementTree(root)
    #tree.write("output.xml", encoding="UTF-8")
    tree.write(fileOutputXml, encoding="UTF-8")
    bar.finish()

print('Выполнено')
# Out:
# Обработка файла DFObjects.txt
# Выгрузка файла output.txt
# Выполнено

# %%
types = {}
for ln in propTable:
  type = ln[2]
  if type in types:
    types[type] +=1
  else:
    types[type] = 1
types
# Out:
# {'root': 1,
#  'object': 100,
#  'section': 537,
#  'property': 10802,
#  'field': 1152,
#  'trigger': 709,
#  'cal': 42289,
#  'var': 5011,
#  'key': 71,
#  'procedure': 1393,
#  'param': 1857,
#  'documentation': 1107,
#  'control': 2714}

# %%
propTable[1:10]
# Out:
# [[1, 0, 'object', 'Neptun Focus Agents Setup', 'Table', '550000', 1, 0],
#  [2, 1, 'section', 'OBJECT-PROPERTIES', '', '', 3, 2],
#  [3, 2, 'property', 'Date', '', '05.04.18;', 5, 4, ''],
#  [4, 2, 'property', 'Time', '', '20:03:42;', 6, 4, ''],
#  [5, 2, 'property', 'Modified', '', 'Yes;', 7, 4, ''],
#  [6, 2, 'property', 'Version List', '', '[kp8712 {KP}];', 8, 4, ''],
#  [7, 1, 'section', 'PROPERTIES', '', '', 10, 2],
#  [8, 7, 'property', 'LookupFormID', 'Form', '550001;', 12, 4, ''],
#  [9, 1, 'section', 'FIELDS', '', '', 14, 2]]

# %%
for line in propTable:
    if line[2] == 'property' and line[3] not in ['Date', 'Time','CaptionML','Description','OptionString','OptionCaptionML','Version List']:
        print(line)
# Out:
# [5, 2, 'property', 'Modified', '', 'Yes;', 7, 4, '']
# [20, 19, 'property', 'TableRelation', '', '"Holding Division".No.', 28, 51, '']
# [27, 26, 'property', 'InitValue', '', 'Yes', 37, 51, '']
# [38, 36, 'property', 'MinValue', '', '0', 48, 51, '']
# [40, 39, 'property', 'TableRelation', '', '"Holding Division".No.', 49, 51, '']
# [41, 39, 'property', 'ValidateTableRelation', '', 'No;', 50, 51, '']
# [42, 39, 'property', 'TestTableRelation', '', 'No;', 51, 51, '']
# [55, 53, 'property', 'MinValue', '', '0;', 65, 51, '']
# [56, 53, 'property', 'MaxValue', '', '60;', 66, 51, '']
# [89, 88, 'property', 'Clustered', '', 'Yes', 103, 51, '']
# [94, 93, 'property', 'LCG', '', 'PO CMN4016 12.09.2021 - Удалил процедуру Modifications()', 115, 6, '']
# [95, 93, 'property', 'LCG', '', 'PO KP14026 25.11.2020', 116, 6, '']
# [96, 95, 'property', 'Добавлено', '', 'поле 56100 - "Trg Section Filter" Text30', 117, 8, '']
# [97, 91, 'property', 'END.', '', '', 119, 4, '']
# [102, 99, 'property', 'Modified', '', 'Yes;', 129, 4, '']
# [118, 104, 'property', 'LookupFormID', 'Form', '50282;', 153, 4, '']
# [119, 104, 'property', 'DrillDownFormID', 'Form', '50282;', 154, 4, '']
# [124, 123, 'property', 'TableRelation', '', '"Holding Division".No.', 160, 51, '']
# [152, 151, 'property', 'TableRelation', '', '"Holding Division".No.', 194, 51, '']
# [168, 167, 'property', 'TableRelation', '', 'Customer.No.', 215, 51, '']
# [169, 167, 'property', 'ValidateTableRelation', '', 'No;', 216, 51, '']
# [170, 167, 'property', 'TestTableRelation', '', 'No;', 217, 51, '']
# [173, 172, 'property', 'TableRelation', '', 'Vendor.No.', 220, 51, '']
# [174, 172, 'property', 'ValidateTableRelation', '', 'No;', 221, 51, '']
# [175, 172, 'property', 'TestTableRelation', '', 'No;', 222, 51, '']
# [190, 189, 'property', 'TableRelation', '', 'Location.Code', 239, 51, '']
# [193, 192, 'property', 'TableRelation', '', "IF (Location Code=CONST()) Bin.Code ELSE IF (Location Code=FILTER(<>'')) Bin.Code WHERE (Location Code=FIELD(Location Code))", 242, 51, '']
# [196, 195, 'property', 'TableRelation', '', 'Location.Code', 246, 51, '']
# [199, 198, 'property', 'TableRelation', '', "IF (New Location Code=CONST()) Bin.Code ELSE IF (New Location Code=FILTER(<>'')) Bin.Code WHERE (Location Code=FIELD(New Location Code))", 249, 51, '']
# [226, 225, 'property', 'TableRelation', '', 'Location', 280, 51, '']
# [246, 245, 'property', 'TableRelation', '', '"Holding Division".No.', 303, 51, '']
# [257, 256, 'property', 'TableRelation', '', 'Location', 315, 51, '']
# [258, 256, 'property', 'ValidateTableRelation', '', 'No;', 316, 51, '']
# [259, 256, 'property', 'TestTableRelation', '', 'No;', 317, 51, '']
# [262, 261, 'property', 'TableRelation', '', 'Bin', 320, 51, '']
# [263, 261, 'property', 'ValidateTableRelation', '', 'No;', 321, 51, '']
# [264, 261, 'property', 'TestTableRelation', '', 'No;', 322, 51, '']
# [267, 266, 'property', 'TableRelation', '', 'Location', 325, 51, '']
# [268, 266, 'property', 'ValidateTableRelation', '', 'No;', 326, 51, '']
# [269, 266, 'property', 'TestTableRelation', '', 'No;', 327, 51, '']
# [272, 271, 'property', 'TableRelation', '', 'Bin', 329, 51, '']
# [273, 271, 'property', 'ValidateTableRelation', '', 'No;', 330, 51, '']
# [274, 271, 'property', 'TestTableRelation', '', 'No;', 331, 51, '']
# [277, 276, 'property', 'TableRelation', '', 'Location', 333, 51, '']
# [278, 276, 'property', 'ValidateTableRelation', '', 'No;', 334, 51, '']
# [279, 276, 'property', 'TestTableRelation', '', 'No;', 335, 51, '']
# [282, 281, 'property', 'TableRelation', '', 'Object.ID WHERE (Type=CONST(Table))', 337, 51, '']
# [288, 281, 'property', 'ValidateTableRelation', '', 'No;', 347, 51, '']
# [289, 281, 'property', 'TestTableRelation', '', 'No;', 348, 51, '']
# [291, 281, 'property', 'BlankZero', '', 'Yes', 350, 51, '']
# [293, 292, 'property', 'TableRelation', '', '"Reason Code"', 351, 51, '']
# [294, 292, 'property', 'ValidateTableRelation', '', 'No;', 352, 51, '']
# [404, 403, 'property', 'TableRelation', '', '"Справочники ПЭО".Код WHERE (Тип Справочника=CONST(SupplierBillTo))', 471, 51, '']
# [423, 422, 'property', 'TableRelation', '', '"Shipment Method"', 490, 51, '']
# [424, 422, 'property', 'ValidateTableRelation', '', 'No;', 491, 51, '']
# [425, 422, 'property', 'TestTableRelation', '', 'No;', 492, 51, '']
# [432, 431, 'property', 'TableRelation', '', '"Logistic Object"."Logistic Object Code"', 499, 51, '']
# [436, 435, 'property', 'TableRelation', '', '"DFN Stage".Code', 502, 51, '']
# [445, 444, 'property', 'TableRelation', '', '"DFN Stage".Code', 512, 51, '']
# [446, 444, 'property', 'ValidateTableRelation', '', 'No;', 513, 51, '']
# [447, 444, 'property', 'TestTableRelation', '', 'No;', 514, 51, '']
# [454, 453, 'property', 'TableRelation', '', '"Holding Division".No.', 521, 51, '']
# [455, 453, 'property', 'ValidateTableRelation', '', 'No;', 522, 51, '']
# [456, 453, 'property', 'TestTableRelation', '', 'No;', 523, 51, '']
# [468, 467, 'property', 'TableRelation', '', 'Currency', 536, 51, '']
# [469, 467, 'property', 'ValidateTableRelation', '', 'No;', 537, 51, '']
# [470, 467, 'property', 'TestTableRelation', '', 'No;', 538, 51, '']
# [484, 483, 'property', 'TableRelation', '', '"Shipping Agent"', 553, 51, '']
# [485, 483, 'property', 'ValidateTableRelation', '', 'No;', 554, 51, '']
# [486, 483, 'property', 'TestTableRelation', '', 'No;', 555, 51, '']
# [584, 583, 'property', 'TableRelation', '', '"Correction Code"', 665, 51, '']
# [585, 583, 'property', 'ValidateTableRelation', '', 'No;', 666, 51, '']
# [586, 583, 'property', 'TestTableRelation', '', 'No;', 667, 51, '']
# [608, 607, 'property', 'TableRelation', '', '"DF Event Code".Code', 692, 51, '']
# [624, 623, 'property', 'Clustered', '', 'Yes', 711, 51, '']
# [1152, 1149, 'property', 'Modified', '', 'Yes;', 1327, 4, '']
# [1155, 1154, 'property', 'DataPerCompany', '', 'No;', 1332, 4, '']
# [1171, 1154, 'property', 'LinkedObject', '', 'Yes;', 1352, 4, '']
# [1173, 1154, 'property', 'LookupFormID', 'Form', '50277;', 1355, 4, '']
# [1174, 1154, 'property', 'DrillDownFormID', 'Form', '50277;', 1356, 4, '']
# [1182, 1181, 'property', 'TableRelation', '', '"Holding Division".No.', 1364, 51, '']
# [1251, 1248, 'property', 'MinValue', '', '0;', 1435, 51, '']
# [1257, 1256, 'property', 'TableRelation', '', '"Holding Division".No.', 1440, 51, '']
# [1264, 1263, 'property', 'TableRelation', '', '"DF Document".ID', 1447, 51, '']
# [1267, 1266, 'property', 'TableRelation', '', '"DF Document"."Copy No" WHERE (ID=FIELD(Confirm to ID))', 1450, 51, '']
# [1291, 1290, 'property', 'TableRelation', '', '"Holding Division".No.', 1475, 51, '']
# [1530, 1529, 'property', 'Compressed', '', 'No', 1674, 51, '']
# [1546, 1545, 'property', 'MaintainSIFTIndex', '', 'No', 1691, 51, '']
# [1547, 1545, 'property', 'Clustered', '', 'Yes', 1692, 51, '']
# [1549, 1548, 'property', 'MaintainSQLIndex', '', 'No', 1693, 51, '']
# [1550, 1548, 'property', 'MaintainSIFTIndex', '', 'No', 1694, 51, '']
# [1552, 1551, 'property', 'MaintainSQLIndex', '', 'No', 1695, 51, '']
# [1553, 1551, 'property', 'MaintainSIFTIndex', '', 'No', 1696, 51, '']
# [1555, 1554, 'property', 'MaintainSQLIndex', '', 'Yes', 1697, 51, '']
# [1556, 1554, 'property', 'MaintainSIFTIndex', '', 'No', 1698, 51, '']
# [1558, 1557, 'property', 'KeyGroups', '', 'perfomance', 1699, 51, '']
# [1559, 1557, 'property', 'MaintainSQLIndex', '', 'Yes;', 1700, 51, '']
# [1560, 1557, 'property', 'MaintainSIFTIndex', '', 'No', 1701, 51, '']
# [1562, 1561, 'property', 'KeyGroups', '', 'CMN531', 1702, 51, '']
# [1563, 1561, 'property', 'MaintainSQLIndex', '', 'Yes;', 1703, 51, '']
# [1564, 1561, 'property', 'MaintainSIFTIndex', '', 'No', 1704, 51, '']
# [1566, 1565, 'property', 'KeyGroups', '', 'CMN531', 1705, 51, '']
# [1567, 1565, 'property', 'MaintainSQLIndex', '', 'Yes;', 1706, 51, '']
# [1568, 1565, 'property', 'MaintainSIFTIndex', '', 'No', 1707, 51, '']
# [1570, 1569, 'property', 'KeyGroups', '', 'perfomance CMN540;', 1709, 51, '']
# [1571, 1569, 'property', 'MaintainSIFTIndex', '', 'No', 1710, 51, '']
# [1573, 1572, 'property', 'KeyGroups', '', 'KP343;', 1712, 51, '']
# [1574, 1572, 'property', 'MaintainSQLIndex', '', 'Yes;', 1713, 51, '']
# [1575, 1572, 'property', 'MaintainSIFTIndex', '', 'No', 1714, 51, '']
# [1577, 1576, 'property', 'KeyGroups', '', 'CO1432', 1715, 51, '']
# [1578, 1576, 'property', 'MaintainSQLIndex', '', 'Yes;', 1716, 51, '']
# [1579, 1576, 'property', 'MaintainSIFTIndex', '', 'No', 1717, 51, '']
# [1581, 1580, 'property', 'KeyGroups', '', 'GDR639;', 1719, 51, '']
# [1582, 1580, 'property', 'MaintainSQLIndex', '', 'Yes;', 1720, 51, '']
# [1583, 1580, 'property', 'MaintainSIFTIndex', '', 'No', 1721, 51, '']
# [1585, 1584, 'property', 'MaintainSQLIndex', '', 'No;', 1723, 51, '']
# [1586, 1584, 'property', 'MaintainSIFTIndex', '', 'No', 1724, 51, '']
# [1588, 1587, 'property', 'KeyGroups', '', 'LCG DID CMN1037 07.10.2011', 1725, 51, '']
# [1589, 1587, 'property', 'MaintainSQLIndex', '', 'No;', 1726, 51, '']
# [1590, 1587, 'property', 'MaintainSIFTIndex', '', 'No', 1727, 51, '']
# [1739, 1736, 'property', 'Modified', '', 'Yes;', 1916, 4, '']
# [1742, 1741, 'property', 'DataPerCompany', '', 'No;', 1921, 4, '']
# [1758, 1757, 'property', 'TableRelation', '', '"DF Document".ID', 1941, 51, '']
# [1764, 1763, 'property', 'TableRelation', '', '"Holding Division".No.', 1946, 51, '']
# [1794, 1774, 'property', 'DecimalPlaces', '', '0:', 1980, 51, '']
# [1807, 1805, 'property', 'DecimalPlaces', '', '0:', 1994, 51, '']
# [1810, 1808, 'property', 'DecimalPlaces', '', '0:', 1997, 51, '']
# [1817, 1815, 'property', 'DecimalPlaces', '', '0:', 2005, 51, '']
# [1941, 1940, 'property', 'Clustered', '', 'Yes', 2100, 51, '']
# [1965, 1962, 'property', 'Modified', '', 'Yes;', 2145, 4, '']
# [1968, 1967, 'property', 'DataPerCompany', '', 'No;', 2150, 4, '']
# [1975, 1967, 'property', 'LinkedObject', '', 'Yes;', 2159, 4, '']
# [1979, 1978, 'property', 'TableRelation', '', '"DF Document".ID', 2165, 51, '']
# [1990, 1989, 'property', 'TableRelation', '', '"Holding Division".No.', 2176, 51, '']
# [2036, 2035, 'property', 'Clustered', '', 'Yes', 2221, 51, '']
# [2041, 2040, 'property', 'LCG', '', 'PO CMN4016 12.09.2021 - Удалил процедуру Modifications()', 2233, 6, '']
# [2042, 2040, 'property', 'LCG', '', 'BRE CMN3730 26.08.2020', 2234, 6, '']
# [2043, 2042, 'property', 'Поле', '', '4    - "Object Type": синхронизировал список опций с GDR, доб. опцию "Marking Code"', 2235, 8, '']
# [2044, 2042, 'property', 'Поле', '', '1012 - "Comment": Text100 -> Text250', 2236, 8, '']
# [2045, 2040, 'property', 'LCG', '', 'RMV KP14486 18.04.2021 В Object Type доб. опции Contractor,Bank Account   (Контрагент,Банк. Счет)', 2238, 6, '']
# [2046, 2038, 'property', 'END.', '', '', 2240, 4, '']
# [2053, 2052, 'property', 'DataPerCompany', '', 'No;', 2254, 4, '']
# [2057, 2056, 'property', 'TableRelation', '', '"DF Document".ID', 2260, 51, '']
# [2059, 2058, 'property', 'TableRelation', '', '"DF Document"."Copy No" WHERE (ID=FIELD(DF ID))', 2261, 51, '']
# [2062, 2061, 'property', 'TableRelation', '', '"Holding Division".No.', 2264, 51, '']
# [2065, 2064, 'property', 'TableRelation', '', '"Holding Division".No.', 2267, 51, '']
# [2106, 2105, 'property', 'Clustered', '', 'Yes', 2310, 51, '']
# [2122, 2119, 'property', 'Modified', '', 'Yes;', 2342, 4, '']
# [2126, 2124, 'property', 'LookupFormID', 'Form', '54999;', 2348, 4, '']
# [2129, 2128, 'property', 'TableRelation', '', '"DFN Type"', 2352, 51, '']
# [2132, 2131, 'property', 'TableRelation', '', 'Salesperson/Purchaser', 2354, 51, '']
# [2136, 2135, 'property', 'Clustered', '', 'Yes', 2359, 51, '']
# [2143, 2140, 'property', 'Modified', '', 'Yes;', 2378, 4, '']
# [2161, 2160, 'property', 'TableRelation', '', '"Base Calendar".Code', 2400, 51, '']
# [2172, 2171, 'property', 'TableRelation', '', '"User Role"', 2411, 51, '']
# [2175, 2174, 'property', 'TableRelation', '', '"User Role"', 2414, 51, '']
# [2178, 2177, 'property', 'TableRelation', '', '"User Role"', 2417, 51, '']
# [2181, 2180, 'property', 'TableRelation', '', '"DFN Stage".Code;', 2421, 51, '']
# [2201, 2200, 'property', 'TableRelation', '', '"DFN Stage".Code', 2437, 51, '']
# [2205, 2204, 'property', 'TableRelation', '', '"DFN Stage".Code', 2441, 51, '']
# [2209, 2208, 'property', 'TableRelation', '', '"DFN Stage".Code', 2445, 51, '']
# [2210, 2208, 'property', 'ValidateTableRelation', '', 'No;', 2446, 51, '']
# [2214, 2213, 'property', 'TableRelation', '', '"DFN Stage".Code;', 2451, 51, '']
# [2215, 2213, 'property', 'ValidateTableRelation', '', 'No;', 2452, 51, '']
# [2219, 2218, 'property', 'TableRelation', '', '"DFN Stage".Code;', 2457, 51, '']
# [2220, 2218, 'property', 'ValidateTableRelation', '', 'No;', 2458, 51, '']
# [2241, 2240, 'property', 'TableRelation', '', '"DFN Stage".Code', 2483, 51, '']
# [2242, 2240, 'property', 'ValidateTableRelation', '', 'No;', 2484, 51, '']
# [2254, 2253, 'property', 'TableRelation', '', '"DFN Stage".Code', 2497, 51, '']
# [2258, 2257, 'property', 'TableRelation', '', '"DFN Stage".Code', 2501, 51, '']
# [2259, 2257, 'property', 'ValidateTableRelation', '', 'No;', 2502, 51, '']
# [2263, 2262, 'property', 'TableRelation', '', '"User Role"', 2506, 51, '']
# [2309, 2308, 'property', 'TableRelation', '', '"DFN Stage".Code WHERE (Document Type=CONST(6))', 2556, 51, '']
# [2359, 2358, 'property', 'TableRelation', '', '"User Role"', 2610, 51, '']
# [2363, 2362, 'property', 'TableRelation', '', '"User Role"', 2613, 51, '']
# [2367, 2366, 'property', 'TableRelation', '', 'Vendor', 2617, 51, '']
# [2386, 2385, 'property', 'TableRelation', '', '"DFN Stage".Code', 2635, 51, '']
# [2387, 2385, 'property', 'ValidateTableRelation', '', 'No;', 2636, 51, '']
# [2421, 2420, 'property', 'TableRelation', '', '"DFN Stage".Code WHERE (Document Type=CONST(5))', 2675, 51, '']
# [2443, 2442, 'property', 'TableRelation', '', '"DFN Stage".Code WHERE (Document Type=CONST(6))', 2697, 51, '']
# [2485, 2484, 'property', 'TableRelation', '', '"DFN Stage".Code;', 2748, 51, '']
# [2486, 2484, 'property', 'ValidateTableRelation', '', 'No;', 2749, 51, '']
# [2514, 2513, 'property', 'TableRelation', '', '"DFN Stage".Code WHERE (Document Type=CONST(5))', 2780, 51, '']
# [2519, 2518, 'property', 'MaintainSIFTIndex', '', 'No', 2787, 51, '']
# [2520, 2518, 'property', 'Clustered', '', 'Yes', 2788, 51, '']
# [2547, 2544, 'property', 'Modified', '', 'Yes;', 2829, 4, '']
# [2550, 2549, 'property', 'DataCaptionFields', '', 'ID,Description;', 2834, 4, '']
# [2569, 2549, 'property', 'LookupFormID', 'Form', '55004;', 2861, 4, '']
# [2570, 2549, 'property', 'DrillDownFormID', 'Form', '55004;', 2862, 4, '']
# [2574, 2572, 'property', 'NotBlank', '', 'Yes', 2868, 51, '']
# [2592, 2591, 'property', 'TableRelation', '', '"No. Series"', 2888, 51, '']
# [2597, 2596, 'property', 'TableRelation', '', '"DFN Stage".Code WHERE (Document Type=FIELD(ID))', 2893, 51, '']
# [2600, 2599, 'property', 'TableRelation', '', '"DFN Stage".Code WHERE (Document Type=FIELD(ID))', 2896, 51, '']
# [2603, 2602, 'property', 'TableRelation', '', '"DFN Stage".Code WHERE (Document Type=FIELD(ID))', 2899, 51, '']
# [2681, 2680, 'property', 'TableRelation', '', '"DFN Stage".Code WHERE (Document Type=FIELD(ID))', 2995, 51, '']
# [2691, 2690, 'property', 'TableRelation', '', '"DFN Stage".Code WHERE (Document Type=FIELD(ID))', 3005, 51, '']
# [2695, 2694, 'property', 'TableRelation', '', '"DFN Stage".Code WHERE (Document Type=FIELD(ID))', 3009, 51, '']
# [2699, 2698, 'property', 'TableRelation', '', '"DFN Stage".Code WHERE (Document Type=FIELD(ID))', 3013, 51, '']
# [2733, 2732, 'property', 'FieldClass', '', 'FlowFilter', 3056, 51, '']
# [2736, 2735, 'property', 'FieldClass', '', 'FlowField', 3059, 51, '']
# [2737, 2735, 'property', 'CalcFormula', '', 'Count("DFN Document Card" WHERE (DF Type=FIELD(ID)));', 3060, 51, '']
# [2740, 2739, 'property', 'FieldClass', '', 'FlowField', 3063, 51, '']
# [2741, 2739, 'property', 'CalcFormula', '', 'Count("DFN Document Card" WHERE (DF Type=FIELD(ID), Plan DT=FIELD(Date Filter), Activity=CONST(Yes)))', 3064, 51, '']
# [2744, 2743, 'property', 'FieldClass', '', 'FlowField', 3069, 51, '']
# [2745, 2743, 'property', 'CalcFormula', '', 'Count("DFN Document Card" WHERE (DF Type=FIELD(ID), Limit DT=FIELD(Date Filter), Activity=CONST(Yes)))', 3070, 51, '']
# [2990, 2989, 'property', 'TableRelation', '', '"DFN Stage".Code WHERE (Document Type=FIELD(ID))', 3397, 51, '']
# [2993, 2992, 'property', 'TableRelation', '', '"DFN Stage".Code WHERE (Document Type=FIELD(ID))', 3400, 51, '']
# [2996, 2995, 'property', 'TableRelation', '', '"DFN Stage".Code WHERE (Document Type=FIELD(ID))', 3403, 51, '']
# [2999, 2998, 'property', 'FieldClass', '', 'FlowField', 3406, 51, '']
# [3000, 2998, 'property', 'CalcFormula', '', 'Count("DFN Log" WHERE (DF Type=FIELD(ID), Execute DT=FIELD(Date Filter), Stage From=FIELD(Stage Filter), Executor Role=FIELD(DF Role Filter), Executor Salesperson=FIELD(SalesPerson Filter), Controller=FIELD(Team Filter)))', 3407, 51, '']
# [3003, 3002, 'property', 'FieldClass', '', 'FlowField', 3415, 51, '']
# [3004, 3002, 'property', 'CalcFormula', '', 'Count("DFN Log" WHERE (DF Type=FIELD(ID), Execute DT=FIELD(Date Filter), Stage From=FIELD(Stage Filter), Executor Role=FIELD(DF Role Filter), Executor Salesperson=FIELD(SalesPerson Filter), Controller=FIELD(Team Filter), Plan Overdue=FILTER(<>0)))', 3416, 51, '']
# [3007, 3006, 'property', 'FieldClass', '', 'FlowField', 3425, 51, '']
# [3008, 3006, 'property', 'CalcFormula', '', 'Count("DFN Log" WHERE (DF Type=FIELD(ID), Execute DT=FIELD(Date Filter), Stage From=FIELD(Stage Filter), Executor Role=FIELD(DF Role Filter), Executor Salesperson=FIELD(SalesPerson Filter), Controller=FIELD(Team Filter), Limit Overdue=FILTER(<>0)))', 3426, 51, '']
# [3011, 3010, 'property', 'FieldClass', '', 'FlowField', 3435, 51, '']
# [3012, 3010, 'property', 'CalcFormula', '', 'Max("DFN Log"."Plan Overdue" WHERE (DF Type=FIELD(ID), Execute DT=FIELD(Date Filter), Stage From=FIELD(Stage Filter), Executor Role=FIELD(DF Role Filter), Executor Salesperson=FIELD(SalesPerson Filter), Controller=FIELD(Team Filter)))', 3436, 51, '']
# [3015, 3014, 'property', 'FieldClass', '', 'FlowField', 3444, 51, '']
# [3016, 3014, 'property', 'CalcFormula', '', 'Max("DFN Log"."Limit Overdue" WHERE (DF Type=FIELD(ID), Execute DT=FIELD(Date Filter), Stage From=FIELD(Stage Filter), Executor Role=FIELD(DF Role Filter), Executor Salesperson=FIELD(SalesPerson Filter), Controller=FIELD(Team Filter)))', 3445, 51, '']
# [3019, 3018, 'property', 'FieldClass', '', 'FlowFilter', 3453, 51, '']
# [3020, 3018, 'property', 'TableRelation', '', '"DFN Setup";', 3454, 51, '']
# [3023, 3022, 'property', 'FieldClass', '', 'FlowFilter', 3457, 51, '']
# [3024, 3022, 'property', 'TableRelation', '', '"DFN Type".Description WHERE (ID=FIELD(ID));', 3458, 51, '']
# [3027, 3026, 'property', 'FieldClass', '', 'FlowFilter', 3461, 51, '']
# [3028, 3026, 'property', 'TableRelation', '', '"DFN Stage";', 3462, 51, '']
# [3031, 3030, 'property', 'FieldClass', '', 'FlowFilter', 3465, 51, '']
# [3032, 3030, 'property', 'TableRelation', '', 'Team;', 3466, 51, '']
# [3049, 3048, 'property', 'TableRelation', '', '"DFN Stage".Code WHERE (Document Type=FIELD(ID))', 3483, 51, '']
# [3053, 3052, 'property', 'TableRelation', '', '"DFN Stage".Code WHERE (Document Type=FIELD(ID))', 3487, 51, '']
# [3058, 3057, 'property', 'MaintainSIFTIndex', '', 'No', 3494, 51, '']
# [3059, 3057, 'property', 'Clustered', '', 'Yes', 3495, 51, '']
# [3274, 3271, 'property', 'Modified', '', 'Yes;', 3750, 4, '']
# [3277, 3276, 'property', 'DataCaptionFields', '', 'Document Type,Code,Description;', 3755, 4, '']
# [3281, 3276, 'property', 'LookupFormID', 'Form', '55005;', 3762, 4, '']
# [3282, 3276, 'property', 'DrillDownFormID', 'Form', '55005;', 3763, 4, '']
# [3285, 3284, 'property', 'TableRelation', '', '"DFN Type"', 3767, 51, '']
# [3312, 3311, 'property', 'FieldClass', '', 'FlowFilter', 3797, 51, '']
# [3345, 3344, 'property', 'Clustered', '', 'Yes', 3831, 51, '']
# [3385, 3382, 'property', 'Modified', '', 'Yes;', 3899, 4, '']
# [3433, 3432, 'property', 'TableRelation', '', '"DFN Type"', 3966, 51, '']
# [3436, 3435, 'property', 'TableRelation', '', '"DFN Stage".Code WHERE (Document Type=FIELD(DF Type))', 3969, 51, '']
# [3439, 3438, 'property', 'TableRelation', '', '"DFN Stage".Code WHERE (Document Type=FIELD(DF Type))', 3972, 51, '']
# [3442, 3441, 'property', 'TableRelation', '', '"User Role"."Role ID"', 3975, 51, '']
# [3469, 3468, 'property', 'InitValue', '', 'Yes', 4011, 51, '']
# [3472, 3471, 'property', 'FieldClass', '', 'FlowField', 4014, 51, '']
# [3473, 3471, 'property', 'CalcFormula', '', 'Count("DFN Condition" WHERE (Gen. Dir. Rec. ID=FIELD(Record ID)));', 4015, 51, '']
# [3537, 3536, 'property', 'TableRelation', '', 'Field.No. WHERE (TableNo=FIELD(Source Table No.))', 4092, 51, '']
# [3554, 3553, 'property', 'FieldClass', '', 'FlowField', 4117, 51, '']
# [3555, 3553, 'property', 'CalcFormula', '', 'Lookup(Field."Field Caption" WHERE (TableNo=FIELD(Source Table No.), No.=FIELD(Field No.)))', 4118, 51, '']
# [3619, 3618, 'property', 'TableRelation', '', 'IF (Executor Type=CONST(Salesperson)) Salesperson/Purchaser.Code ELSE IF (Executor Type=CONST(Role)) "User Role"."Role ID" WHERE (Role ID=FILTER(RTRET))', 4192, 51, '']
# [3671, 3670, 'property', 'TableRelation', '', 'Team', 4256, 51, '']
# [3678, 3677, 'property', 'TableRelation', '', 'Salesperson/Purchaser', 4263, 51, '']
# [3705, 3704, 'property', 'FieldClass', '', 'FlowField', 4297, 51, '']
# [3706, 3704, 'property', 'CalcFormula', '', 'Lookup(Field."Field Caption" WHERE (TableNo=FIELD(Source Table No.), No.=FIELD(Date From Field No.)))', 4298, 51, '']
# [3709, 3708, 'property', 'InitValue', '', '12:00:00', 4302, 51, '']
# [3741, 3727, 'property', 'NotBlank', '', 'Yes', 4344, 51, '']
# [3747, 3746, 'property', 'InitValue', '', 'Yes', 4349, 51, '']
# [3750, 3749, 'property', 'InitValue', '', 'Yes', 4352, 51, '']
# [3764, 3758, 'property', 'MinValue', '', '1', 4373, 51, '']
# [3768, 3767, 'property', 'FieldClass', '', 'FlowField', 4376, 51, '']
# [3769, 3767, 'property', 'CalcFormula', '', 'Count("DFN Report Packet" WHERE (DF Type ID=FIELD(DF Type), Packet Code=FIELD(Packet Code)))', 4377, 51, '']
# [3782, 3781, 'property', 'TableRelation', '', '"DFN Stage".Code WHERE (Document Type=FIELD(DF Type))', 4395, 51, '']
# [3818, 3817, 'property', 'TableRelation', '', 'Salesperson/Purchaser.Code', 4436, 51, '']
# [3881, 3880, 'property', 'TableRelation', '', 'Dimension', 4508, 51, '']
# [3883, 3880, 'property', 'NotBlank', '', 'Yes', 4511, 51, '']
# [3885, 3884, 'property', 'TableRelation', '', '"Dimension Value".Code WHERE (Dimension Code=FIELD(Dimension Code))', 4512, 51, '']
# [3905, 3904, 'property', 'TableRelation', '', '"Dimension Value".Code WHERE (Dimension Code=FIELD(Dimension Code))', 4535, 51, '']
# [3906, 3904, 'property', 'ValidateTableRelation', '', 'No;', 4536, 51, '']
# [3907, 3904, 'property', 'TestTableRelation', '', 'No;', 4537, 51, '']
# [3927, 3926, 'property', 'FieldClass', '', 'FlowField', 4559, 51, '']
# [3928, 3926, 'property', 'CalcFormula', '', 'Lookup("DFN Type".Description WHERE (ID=FIELD(DF Type)))', 4560, 51, '']
# [3945, 3944, 'property', 'FieldClass', '', 'FlowField', 4572, 51, '']
# [3946, 3944, 'property', 'CalcFormula', '', 'Count("DFN General Directory" WHERE (Parrent Settings Line No.=FIELD(Line No.)));', 4573, 51, '']
# [3949, 3944, 'property', 'Editable', '', 'No', 4576, 51, '']
# [3964, 3963, 'property', 'MaintainSIFTIndex', '', 'No', 4590, 51, '']
# [3965, 3963, 'property', 'Clustered', '', 'Yes', 4591, 51, '']
# [3967, 3966, 'property', 'KeyGroups', '', 'main', 4592, 51, '']
# [3969, 3968, 'property', 'KeyGroups', '', 'DF Type group', 4593, 51, '']
# [3971, 3970, 'property', 'KeyGroups', '', 'Stage group', 4595, 51, '']
# [4269, 4266, 'property', 'Modified', '', 'Yes;', 4977, 4, '']
# [4287, 4271, 'property', 'DrillDownFormID', 'Form', '55009;', 5006, 4, '']
# [4306, 4305, 'property', 'InitValue', '', 'Yes', 5029, 51, '']
# [4311, 4309, 'property', 'MinValue', '', '1', 5035, 51, '']
# [4345, 4344, 'property', 'TableRelation', '', 'Field.No. WHERE (TableNo=FIELD(Table ID), Type=CONST(5))', 5074, 51, '']
# [4354, 4353, 'property', 'FieldClass', '', 'FlowField', 5090, 51, '']
# [4355, 4353, 'property', 'CalcFormula', '', 'Exist("DFN General Directory" WHERE (Record ID=FIELD(Gen. Dir. Rec. ID)))', 5091, 51, '']
# [4357, 4356, 'property', 'FieldClass', '', 'FlowField', 5092, 51, '']
# [4358, 4356, 'property', 'CalcFormula', '', 'Lookup("DFN General Directory"."DF Type" WHERE (Record ID=FIELD(Gen. Dir. Rec. ID)))', 5093, 51, '']
# [4363, 4362, 'property', 'MaintainSIFTIndex', '', 'No', 5098, 51, '']
# [4364, 4362, 'property', 'Clustered', '', 'Yes', 5099, 51, '']
# [4366, 4365, 'property', 'SQLIndex', '', 'Gen. Dir. Rec. ID', 5100, 51, '']
# [4415, 4413, 'property', 'LookupFormID', 'Form', '55013;', 5176, 4, '']
# [4416, 4413, 'property', 'DrillDownFormID', 'Form', '55013;', 5177, 4, '']
# [4421, 4420, 'property', 'TableRelation', '', 'Language', 5183, 51, '']
# [4423, 4420, 'property', 'NotBlank', '', 'Yes', 5186, 51, '']
# [4428, 4427, 'property', 'Clustered', '', 'Yes', 5192, 51, '']
# [4440, 4436, 'property', 'LookupFormID', 'Form', '55007;', 5221, 4, '']
# [4441, 4436, 'property', 'DrillDownFormID', 'Form', '55007;', 5222, 4, '']
# [4447, 4446, 'property', 'NotBlank', '', 'Yes', 5229, 51, '']
# [4451, 4450, 'property', 'InitValue', '', '1', 5232, 51, '']
# [4455, 4454, 'property', 'Clustered', '', 'Yes', 5239, 51, '']
# [4527, 4496, 'property', 'LookupFormID', 'Form', '55019;', 5354, 4, '']
# [4528, 4496, 'property', 'DrillDownFormID', 'Form', '55019;', 5355, 4, '']
# [4531, 4530, 'property', 'TableRelation', '', '"DFN Type"', 5359, 51, '']
# [4558, 4557, 'property', 'TableRelation', '', '"DFN Stage".Code WHERE (Document Type=FIELD(DF Type))', 5395, 51, '']
# [4565, 4564, 'property', 'FieldClass', '', 'FlowField', 5402, 51, '']
# [4566, 4564, 'property', 'CalcFormula', '', 'Lookup("DFN Type".Description WHERE (ID=FIELD(DF Type)));', 5403, 51, '']
# [4575, 4574, 'property', 'TableRelation', '', 'Salesperson/Purchaser', 5412, 51, '']
# [4578, 4577, 'property', 'TableRelation', '', 'Team.Code', 5415, 51, '']
# [4583, 4582, 'property', 'TableRelation', '', 'To-do', 5420, 51, '']
# [4587, 4585, 'property', 'CaptionClass', '', 'SetCaption(200)', 5425, 51, '']
# [4590, 4588, 'property', 'CaptionClass', '', 'SetCaption(201)', 5428, 51, '']
# [4593, 4591, 'property', 'CaptionClass', '', 'SetCaption(202)', 5431, 51, '']
# [4596, 4594, 'property', 'CaptionClass', '', 'SetCaption(203)', 5434, 51, '']
# [4599, 4597, 'property', 'CaptionClass', '', 'SetCaption(204)', 5437, 51, '']
# [4602, 4600, 'property', 'CaptionClass', '', 'SetCaption(205)', 5440, 51, '']
# [4605, 4603, 'property', 'CaptionClass', '', 'SetCaption(206)', 5443, 51, '']
# [4608, 4606, 'property', 'CaptionClass', '', 'SetCaption(207)', 5446, 51, '']
# [4611, 4609, 'property', 'CaptionClass', '', 'SetCaption(208)', 5449, 51, '']
# [4614, 4612, 'property', 'CaptionClass', '', 'SetCaption(209)', 5452, 51, '']
# [4617, 4615, 'property', 'CaptionClass', '', 'SetCaption(210)', 5455, 51, '']
# [4620, 4618, 'property', 'CaptionClass', '', 'SetCaption(211)', 5458, 51, '']
# [4623, 4621, 'property', 'CaptionClass', '', 'SetCaption(212)', 5461, 51, '']
# [4626, 4624, 'property', 'CaptionClass', '', 'SetCaption(213)', 5464, 51, '']
# [4629, 4627, 'property', 'CaptionClass', '', 'SetCaption(214)', 5467, 51, '']
# [4632, 4630, 'property', 'CaptionClass', '', 'SetCaption(215)', 5470, 51, '']
# [4635, 4633, 'property', 'CaptionClass', '', 'SetCaption(216)', 5473, 51, '']
# [4638, 4636, 'property', 'CaptionClass', '', 'SetCaption(217)', 5476, 51, '']
# [4641, 4639, 'property', 'CaptionClass', '', 'SetCaption(218)', 5479, 51, '']
# [4644, 4642, 'property', 'CaptionClass', '', 'SetCaption(219)', 5482, 51, '']
# [4650, 4649, 'property', 'Clustered', '', 'Yes', 5489, 51, '']
# [4653, 4652, 'property', 'KeyGroups', '', 'CMN2486', 5491, 51, '']
# [4654, 4652, 'property', 'MaintainSQLIndex', '', 'Yes;', 5492, 51, '']
# [4655, 4652, 'property', 'MaintainSIFTIndex', '', 'No', 5493, 51, '']
# [4723, 4720, 'property', 'Modified', '', 'Yes;', 5597, 4, '']
# [4727, 4725, 'property', 'LookupFormID', 'Form', '55020;', 5604, 4, '']
# [4728, 4725, 'property', 'DrillDownFormID', 'Form', '55020;', 5605, 4, '']
# [4731, 4730, 'property', 'AutoIncrement', '', 'Yes', 5609, 51, '']
# [4735, 4734, 'property', 'TableRelation', '', '"DFN Setup"."Primary Key"', 5613, 51, '']
# [4746, 4745, 'property', 'TableRelation', '', '"DFN Stage".Code WHERE (Document Type=FIELD(DF Type))', 5625, 51, '']
# [4749, 4748, 'property', 'TableRelation', '', '"User Role"', 5628, 51, '']
# [4754, 4753, 'property', 'TableRelation', '', 'Team.Code', 5633, 51, '']
# [4761, 4760, 'property', 'TableRelation', '', '"DFN Stage".Code WHERE (Document Type=FIELD(DF Type))', 5640, 51, '']
# [4764, 4763, 'property', 'TableRelation', '', '"User Role"', 5643, 51, '']
# [4804, 4803, 'property', 'FieldClass', '', 'FlowField', 5678, 51, '']
# [4805, 4803, 'property', 'CalcFormula', '', 'Lookup(Salesperson/Purchaser.Name WHERE (Code=FIELD(Executor Salesperson)));', 5679, 51, '']
# [4808, 4803, 'property', 'Editable', '', 'No', 5682, 51, '']
# [4814, 4813, 'property', 'MaintainSIFTIndex', '', 'No', 5688, 51, '']
# [4815, 4813, 'property', 'Clustered', '', 'Yes', 5689, 51, '']
# [4817, 4816, 'property', 'MaintainSIFTIndex', '', 'No', 5690, 51, '']
# [4819, 4818, 'property', 'MaintainSQLIndex', '', 'No', 5691, 51, '']
# [4821, 4820, 'property', 'MaintainSIFTIndex', '', 'No', 5693, 51, '']
# [4833, 4832, 'property', 'TableRelation', '', '"DFN Type".ID', 5721, 51, '']
# [4837, 4836, 'property', 'TableRelation', '', 'Salesperson/Purchaser.Code', 5724, 51, '']
# [4840, 4839, 'property', 'TableRelation', '', '"DFN General Directory"."Line No." WHERE (Type Of Directory=CONST(NotificationTemplate), DF Type=FIELD(DF Type))', 5727, 51, '']
# [4850, 4849, 'property', 'FieldClass', '', 'FlowField', 5737, 51, '']
# [4851, 4849, 'property', 'CalcFormula', '', 'Lookup("DFN General Directory"."Template Code" WHERE (Line No.=FIELD(Rule Line No.)));', 5738, 51, '']
# [4862, 4861, 'property', 'Clustered', '', 'Yes', 5749, 51, '']
# [4874, 4871, 'property', 'Modified', '', 'Yes;', 5776, 4, '']
# [4889, 4888, 'property', 'TableRelation', '', '"DFN Setup"."Primary Key"', 5797, 51, '']
# [4896, 4895, 'property', 'TableRelation', '', '"DFN Stage".Code WHERE (Document Type=FIELD(DF Type))', 5804, 51, '']
# [4971, 4968, 'property', 'Editable', '', 'No', 5881, 51, '']
# [5086, 5085, 'property', 'Clustered', '', 'Yes', 6006, 51, '']
# [5088, 5087, 'property', 'KeyGroups', '', 'CMN2486', 6007, 51, '']
# [5089, 5087, 'property', 'MaintainSIFTIndex', '', 'No', 6008, 51, '']
# [5104, 5101, 'property', 'Modified', '', 'Yes;', 6040, 4, '']
# [5159, 5106, 'property', 'LookupFormID', 'Form', '55021;', 6112, 4, '']
# [5160, 5106, 'property', 'DrillDownFormID', 'Form', '55021;', 6113, 4, '']
# [5165, 5164, 'property', 'TableRelation', '', '"DFN Type"', 6119, 51, '']
# [5198, 5171, 'property', 'NotBlank', '', 'Yes', 6156, 51, '']
# [5203, 5201, 'property', 'NotBlank', '', 'Yes;', 6161, 51, '']
# [5204, 5201, 'property', 'Editable', '', 'No', 6162, 51, '']
# [5298, 5295, 'property', 'Editable', '', 'No', 6259, 51, '']
# [5304, 5303, 'property', 'MaintainSIFTIndex', '', 'No', 6266, 51, '']
# [5305, 5303, 'property', 'Clustered', '', 'Yes', 6267, 51, '']
# [5307, 5306, 'property', 'MaintainSIFTIndex', '', 'No', 6268, 51, '']
# [5309, 5308, 'property', 'MaintainSIFTIndex', '', 'No', 6269, 51, '']
# [5628, 5625, 'property', 'Modified', '', 'Yes;', 6652, 4, '']
# [5631, 5630, 'property', 'DataPerCompany', '', 'No;', 6657, 4, '']
# [5632, 5630, 'property', 'Permissions', '', 'TableData 50106=rd;', 6658, 4, '']
# [5663, 5630, 'property', 'LookupFormID', 'Form', '50030;', 6697, 4, '']
# [5664, 5630, 'property', 'DrillDownFormID', 'Form', '50030;', 6698, 4, '']
# [5667, 5666, 'property', 'AutoIncrement', '', 'Yes', 6702, 51, '']
# [5670, 5669, 'property', 'TableRelation', '', '"DFN Type"', 6705, 51, '']
# [5698, 5697, 'property', 'FieldClass', '', 'FlowField', 6734, 51, '']
# [5699, 5697, 'property', 'CalcFormula', '', 'Count("DFN Message Recipients" WHERE (Message Id=FIELD(Message Id)));', 6735, 51, '']
# [5701, 5697, 'property', 'Editable', '', 'No', 6738, 51, '']
# [5703, 5702, 'property', 'FieldClass', '', 'FlowField', 6739, 51, '']
# [5704, 5702, 'property', 'CalcFormula', '', 'Lookup("DFN Message Recipients"."Recipient Address" WHERE (Message Id=FIELD(Message Id)));', 6740, 51, '']
# [5725, 5724, 'property', 'TableRelation', '', '"User Role"."Role ID"', 6758, 51, '']
# [5732, 5731, 'property', 'TableRelation', '', '"DFN Stage".Code', 6764, 51, '']
# [5737, 5736, 'property', 'MaintainSIFTIndex', '', 'No', 6771, 51, '']
# [5738, 5736, 'property', 'Clustered', '', 'Yes', 6772, 51, '']
# [5740, 5739, 'property', 'MaintainSIFTIndex', '', 'No', 6773, 51, '']
# [5752, 5751, 'property', 'DataPerCompany', '', 'No;', 6801, 4, '']
# [5768, 5767, 'property', 'MaintainSIFTIndex', '', 'No', 6824, 51, '']
# [5769, 5767, 'property', 'Clustered', '', 'Yes', 6825, 51, '']
# [5791, 5790, 'property', 'InitValue', '', 'Yes', 6863, 51, '']
# [5798, 5797, 'property', 'FieldClass', '', 'Normal', 6870, 51, '']
# [5800, 5797, 'property', 'AutoFormatType', '', '1', 6873, 51, '']
# [5802, 5801, 'property', 'FieldClass', '', 'FlowFilter', 6874, 51, '']
# [5805, 5804, 'property', 'FieldClass', '', 'FlowFilter', 6877, 51, '']
# [5808, 5807, 'property', 'FieldClass', '', 'FlowFilter', 6880, 51, '']
# [5811, 5810, 'property', 'FieldClass', '', 'FlowFilter', 6883, 51, '']
# [5816, 5815, 'property', 'FieldClass', '', 'Normal', 6888, 51, '']
# [5818, 5815, 'property', 'DecimalPlaces', '', '0:5', 6891, 51, '']
# [5821, 5820, 'property', 'MaintainSIFTIndex', '', 'No', 6895, 51, '']
# [5822, 5820, 'property', 'Clustered', '', 'Yes', 6896, 51, '']
# [5824, 5823, 'property', 'MaintainSIFTIndex', '', 'No', 6897, 51, '']
# [5826, 5825, 'property', 'MaintainSQLIndex', '', 'No', 6898, 51, '']
# [5827, 5825, 'property', 'MaintainSIFTIndex', '', 'No', 6899, 51, '']
# [5848, 5847, 'property', 'MaintainSIFTIndex', '', 'No', 6938, 51, '']
# [5849, 5847, 'property', 'Clustered', '', 'Yes', 6939, 51, '']
# [5867, 5866, 'property', 'Clustered', '', 'Yes', 6974, 51, '']
# [5874, 5871, 'property', 'Modified', '', 'Yes;', 6993, 4, '']
# [5878, 5876, 'property', 'LookupFormID', 'Form', '50509;', 6999, 4, '']
# [5881, 5880, 'property', 'TableRelation', '', '"DFN Type"', 7003, 51, '']
# [5884, 5883, 'property', 'TableRelation', '', '"User Setup"."User ID"', 7006, 51, '']
# [5896, 5883, 'property', 'NotBlank', '', 'Yes', 7021, 51, '']
# [5898, 5897, 'property', 'TableRelation', '', 'Object.ID WHERE (Type=CONST(Table))', 7022, 51, '']
# [5901, 5897, 'property', 'NotBlank', '', 'Yes', 7027, 51, '']
# [5903, 5902, 'property', 'TableRelation', '', 'IF (Таблица Но.=FILTER(<>0)) Field.No. WHERE (TableNo=FIELD(Таблица Но.))', 7028, 51, '']
# [5925, 5902, 'property', 'NotBlank', '', 'Yes', 7052, 51, '']
# [5928, 5927, 'property', 'FieldClass', '', 'FlowField', 7054, 51, '']
# [5929, 5927, 'property', 'CalcFormula', '', 'Lookup(Object.Name WHERE (Type=CONST(Table), ID=FIELD(Таблица Но.)))', 7055, 51, '']
# [5930, 5927, 'property', 'Editable', '', 'No', 7057, 51, '']
# [5932, 5931, 'property', 'FieldClass', '', 'FlowField', 7058, 51, '']
# [5933, 5931, 'property', 'CalcFormula', '', 'Lookup(Field.FieldName WHERE (TableNo=FIELD(Таблица Но.), No.=FIELD(Поле Но.)))', 7059, 51, '']
# [5934, 5931, 'property', 'Editable', '', 'No', 7061, 51, '']
# [5940, 5939, 'property', 'Clustered', '', 'Yes', 7068, 51, '']
# [5998, 5995, 'property', 'Modified', '', 'Yes;', 7150, 4, '']
# [6013, 6012, 'property', 'TableRelation', '', 'Field.No. WHERE (TableNo=FIELD(Source Table No.))', 7167, 51, '']
# [6038, 6037, 'property', 'TableRelation', '', 'Field.No. WHERE (TableNo=FIELD(Source Table No.))', 7195, 51, '']
# [6049, 6048, 'property', 'FieldClass', '', 'FlowField', 7205, 51, '']
# [6050, 6048, 'property', 'CalcFormula', '', 'Lookup(Field."Field Caption" WHERE (TableNo=FIELD(Source Table No.), No.=FIELD(Source Fileld No.)))', 7206, 51, '']
# [6056, 6055, 'property', 'Clustered', '', 'Yes', 7214, 51, '']
# [6118, 6117, 'property', 'AutoIncrement', '', 'Yes', 7310, 51, '']
# [6140, 6139, 'property', 'Clustered', '', 'Yes', 7333, 51, '']
# [6149, 6146, 'property', 'Modified', '', 'Yes;', 7354, 4, '']
# [6153, 6151, 'property', 'LookupFormID', 'Form', '99527;', 7361, 4, '']
# [6154, 6151, 'property', 'DrillDownFormID', 'Form', '99527;', 7362, 4, '']
# [6162, 6161, 'property', 'Clustered', '', 'Yes', 7373, 51, '']
# [6170, 6167, 'property', 'Modified', '', 'Yes;', 7395, 4, '']
# [6173, 6172, 'property', 'DataPerCompany', '', 'No;', 7400, 4, '']
# [6193, 6172, 'property', 'LinkedObject', '', 'Yes;', 7422, 4, '']
# [6195, 6172, 'property', 'LookupFormID', 'Form', '99001577;', 7425, 4, '']
# [6196, 6172, 'property', 'DrillDownFormID', 'Form', '99001577;', 7426, 4, '']
# [6204, 6203, 'property', 'TableRelation', '', '"Holding Division".No.', 7434, 51, '']
# [6269, 6266, 'property', 'MinValue', '', '0;', 7502, 51, '']
# [6275, 6274, 'property', 'TableRelation', '', '"Holding Division".No.', 7507, 51, '']
# [6282, 6281, 'property', 'TableRelation', '', '"DF Document".ID', 7514, 51, '']
# [6285, 6284, 'property', 'TableRelation', '', '"DF Document"."Copy No" WHERE (ID=FIELD(Confirm to ID))', 7517, 51, '']
# [6309, 6308, 'property', 'TableRelation', '', '"Holding Division".No.', 7542, 51, '']
# [6501, 6500, 'property', 'Compressed', '', 'No', 7709, 51, '']
# [6505, 6504, 'property', 'MaintainSIFTIndex', '', 'No', 7714, 51, '']
# [6506, 6504, 'property', 'Clustered', '', 'Yes', 7715, 51, '']
# [6508, 6507, 'property', 'MaintainSQLIndex', '', 'Yes', 7716, 51, '']
# [6509, 6507, 'property', 'MaintainSIFTIndex', '', 'No', 7717, 51, '']
# [6511, 6510, 'property', 'MaintainSQLIndex', '', 'Yes', 7718, 51, '']
# [6512, 6510, 'property', 'MaintainSIFTIndex', '', 'No', 7719, 51, '']
# [6514, 6513, 'property', 'KeyGroups', '', 'CMN531', 7720, 51, '']
# [6515, 6513, 'property', 'MaintainSQLIndex', '', 'Yes;', 7721, 51, '']
# [6516, 6513, 'property', 'MaintainSIFTIndex', '', 'No', 7722, 51, '']
# [6518, 6517, 'property', 'KeyGroups', '', 'CMN531', 7723, 51, '']
# [6519, 6517, 'property', 'MaintainSQLIndex', '', 'Yes;', 7724, 51, '']
# [6520, 6517, 'property', 'MaintainSIFTIndex', '', 'No', 7725, 51, '']
# [6522, 6521, 'property', 'KeyGroups', '', 'perfomance CMN540;', 7727, 51, '']
# [6523, 6521, 'property', 'MaintainSQLIndex', '', 'Yes;', 7728, 51, '']
# [6524, 6521, 'property', 'MaintainSIFTIndex', '', 'No', 7729, 51, '']
# [6605, 6602, 'property', 'Modified', '', 'Yes;', 7843, 4, '']
# [6608, 6607, 'property', 'DataPerCompany', '', 'No;', 7848, 4, '']
# [6609, 6607, 'property', 'LinkedObject', '', 'Yes;', 7849, 4, '']
# [6613, 6612, 'property', 'TableRelation', '', '"DF Document Arc".ID', 7855, 51, '']
# [6619, 6618, 'property', 'TableRelation', '', '"Holding Division".No.', 7860, 51, '']
# [6631, 6629, 'property', 'DecimalPlaces', '', '0:', 7874, 51, '']
# [6644, 6642, 'property', 'DecimalPlaces', '', '0:', 7888, 51, '']
# [6647, 6645, 'property', 'DecimalPlaces', '', '0:', 7891, 51, '']
# [6654, 6652, 'property', 'DecimalPlaces', '', '0:', 7899, 51, '']
# [6731, 6730, 'property', 'Clustered', '', 'Yes', 7959, 51, '']
# [6742, 6741, 'property', 'DataPerCompany', '', 'No;', 7986, 4, '']
# [6743, 6741, 'property', 'LinkedObject', '', 'No;', 7987, 4, '']
# [6747, 6746, 'property', 'TableRelation', '', '"DF Document Arc".ID', 7993, 51, '']
# [6757, 6756, 'property', 'TableRelation', '', '"Holding Division".No.', 8003, 51, '']
# [6800, 6799, 'property', 'Clustered', '', 'Yes', 8045, 51, '']
# [6810, 6809, 'property', 'DataPerCompany', '', 'No;', 8071, 4, '']
# [6811, 6809, 'property', 'LinkedObject', '', 'Yes;', 8072, 4, '']
# [6815, 6814, 'property', 'TableRelation', '', '"DF Document Arc".ID', 8078, 51, '']
# [6817, 6816, 'property', 'TableRelation', '', '"DF Document Arc"."Copy No" WHERE (ID=FIELD(DF ID))', 8079, 51, '']
# [6820, 6819, 'property', 'TableRelation', '', '"Holding Division".No.', 8082, 51, '']
# [6823, 6822, 'property', 'TableRelation', '', '"Holding Division".No.', 8085, 51, '']
# [6856, 6855, 'property', 'Clustered', '', 'Yes', 8120, 51, '']
# [6866, 6863, 'property', 'Modified', '', 'Yes;', 8145, 4, '']
# [6869, 6868, 'property', 'Width', '', '11550;', 8150, 4, '']
# [6870, 6868, 'property', 'Height', '', '10670;', 8151, 4, '']
# [6871, 6868, 'property', 'BackColor', '', '16777215;', 8152, 4, '']
# [6875, 6874, 'property', 'FocusOnClick', '', 'Yes', 8158, 49, '']
# [6876, 6874, 'property', 'HorzAlign', '', 'Left;', 8159, 49, '']
# [6877, 6874, 'property', 'BackTransparent', '', 'Yes;', 8160, 49, '']
# [6878, 6874, 'property', 'Border', '', 'No;', 8161, 49, '']
# [6879, 6874, 'property', 'PushAction', '', 'RunObject;', 8162, 49, '']
# [6880, 6874, 'property', 'Bitmap', '', '36;', 8163, 49, '']
# [6882, 6874, 'property', 'RunObject', 'Form', '50270', 8166, 49, '']
# [6884, 6883, 'property', 'FocusOnClick', '', 'Yes', 8167, 49, '']
# [6885, 6883, 'property', 'HorzAlign', '', 'Left;', 8168, 49, '']
# [6886, 6883, 'property', 'BackTransparent', '', 'Yes;', 8169, 49, '']
# [6887, 6883, 'property', 'Border', '', 'No;', 8170, 49, '']
# [6888, 6883, 'property', 'BitmapPos', '', 'Left;', 8171, 49, '']
# [6889, 6883, 'property', 'Bitmap', '', '40;', 8172, 49, '']
# [6891, 6883, 'property', 'Menu', '', 'MENUITEMS', 8175, 49, '']
# [6893, 6892, 'property', 'PushAction', '', 'RunObject;', 8178, 53, '']
# [6895, 6892, 'property', 'RunObject', 'Form', '50279', 8180, 53, '']
# [6897, 6896, 'property', 'PushAction', '', 'RunObject;', 8182, 53, '']
# [6899, 6896, 'property', 'RunObject', 'Form', '55000', 8184, 53, '']
# [6901, 6900, 'property', 'PushAction', '', 'RunObject;', 8186, 53, '']
# [6903, 6900, 'property', 'RunObject', 'Form', '58000', 8188, 53, '']
# [6905, 6904, 'property', 'PushAction', '', 'RunObject;', 8190, 53, '']
# [6907, 6904, 'property', 'RunObject', 'Form', '69070', 8192, 53, '']
# [6909, 6908, 'property', 'FocusOnClick', '', 'Yes', 8195, 49, '']
# [6910, 6908, 'property', 'HorzAlign', '', 'Left;', 8196, 49, '']
# [6911, 6908, 'property', 'BackTransparent', '', 'Yes;', 8197, 49, '']
# [6912, 6908, 'property', 'Border', '', 'No;', 8198, 49, '']
# [6913, 6908, 'property', 'BitmapPos', '', 'Left;', 8199, 49, '']
# [6914, 6908, 'property', 'Bitmap', '', '40;', 8200, 49, '']
# [6916, 6908, 'property', 'Menu', '', 'MENUITEMS', 8203, 49, '']
# [6918, 6917, 'property', 'Visible', '', 'No;', 8206, 53, '']
# [6919, 6917, 'property', 'PushAction', '', 'RunObject;', 8207, 53, '']
# [6921, 6917, 'property', 'RunObject', 'Codeunit', '50070', 8210, 53, '']
# [6923, 6922, 'property', 'FocusOnClick', '', 'Yes', 8213, 49, '']
# [6924, 6922, 'property', 'HorzAlign', '', 'Left;', 8214, 49, '']
# [6925, 6922, 'property', 'BackTransparent', '', 'Yes;', 8215, 49, '']
# [6926, 6922, 'property', 'Border', '', 'No;', 8216, 49, '']
# [6927, 6922, 'property', 'PushAction', '', 'RunObject;', 8217, 49, '']
# [6928, 6922, 'property', 'Bitmap', '', '36;', 8218, 49, '']
# [6930, 6922, 'property', 'RunObject', 'Form', '50272', 8221, 49, '']
# [6932, 6931, 'property', 'FocusOnClick', '', 'Yes', 8222, 49, '']
# [6933, 6931, 'property', 'HorzAlign', '', 'Left;', 8223, 49, '']
# [6934, 6931, 'property', 'BackTransparent', '', 'Yes;', 8224, 49, '']
# [6935, 6931, 'property', 'Border', '', 'No;', 8225, 49, '']
# [6936, 6931, 'property', 'PushAction', '', 'RunObject;', 8226, 49, '']
# [6937, 6931, 'property', 'Bitmap', '', '36;', 8227, 49, '']
# [6939, 6931, 'property', 'RunObject', 'Form', '50277', 8230, 49, '']
# [6941, 6940, 'property', 'HorzGlue', '', 'Right', 8231, 49, '']
# [6942, 6940, 'property', 'VertGlue', '', 'Bottom;', 8232, 49, '']
# [6943, 6940, 'property', 'Bitmap', '', '43', 8233, 49, '']
# [6945, 6944, 'property', 'FontName', '', 'Franklin Gothic Medium', 8234, 49, '']
# [6946, 6944, 'property', 'FontSize', '', '14;', 8235, 49, '']
# [6947, 6944, 'property', 'FontBold', '', 'No;', 8236, 49, '']
# [6948, 6944, 'property', 'LeaderDots', '', 'No;', 8237, 49, '']
# [6951, 6950, 'property', 'Bitmap', '', '41', 8240, 49, '']
# [6953, 6952, 'property', 'FocusOnClick', '', 'Yes;', 8242, 49, '']
# [6954, 6952, 'property', 'HorzAlign', '', 'Left;', 8243, 49, '']
# [6955, 6952, 'property', 'BackTransparent', '', 'Yes;', 8244, 49, '']
# [6956, 6952, 'property', 'Border', '', 'No;', 8245, 49, '']
# [6957, 6952, 'property', 'PushAction', '', 'RunObject;', 8246, 49, '']
# [6958, 6952, 'property', 'Bitmap', '', '36;', 8247, 49, '']
# [6960, 6952, 'property', 'RunObject', 'Form', '99001577', 8250, 49, '']
# [6962, 6961, 'property', 'Bitmap', '', '41', 8251, 49, '']
# [6964, 6963, 'property', 'FocusOnClick', '', 'Yes', 8252, 49, '']
# [6965, 6963, 'property', 'HorzAlign', '', 'Left;', 8253, 49, '']
# [6966, 6963, 'property', 'BackTransparent', '', 'Yes;', 8254, 49, '']
# [6967, 6963, 'property', 'Border', '', 'No;', 8255, 49, '']
# [6968, 6963, 'property', 'PushAction', '', 'RunObject;', 8256, 49, '']
# [6969, 6963, 'property', 'Bitmap', '', '36;', 8257, 49, '']
# [6971, 6963, 'property', 'RunObject', 'Form', '55001', 8260, 49, '']
# [6973, 6972, 'property', 'FontSize', '', '7', 8261, 49, '']
# [6975, 6972, 'property', 'ToolTipML', '', '[ENU=Vendor from Clipboard; RUS=Поставщик из буфера обмена]', 8263, 49, '']
# [7009, 7006, 'property', 'Modified', '', 'Yes;', 8316, 4, '']
# [7012, 7011, 'property', 'Width', '', '16170;', 8321, 4, '']
# [7013, 7011, 'property', 'Height', '', '14300;', 8322, 4, '']
# [7015, 7011, 'property', 'SourceTable', '', 'Table50072;', 8325, 4, '']
# [7016, 7011, 'property', 'SaveTableView', '', 'No;', 8326, 4, '']
# [7017, 7011, 'property', 'DataCaptionExpr', '', 'FIELDCAPTION("No.")+\' = \'+FORMAT("No.")+\' - \'+"Recipient No."+\', \' +FORMAT(Section)+\', \'+DFEvents.EventName(Section,"Event No.");', 8327, 4, '']
# [7022, 7021, 'property', 'HorzGlue', '', 'Both', 8335, 49, '']
# [7023, 7021, 'property', 'VertGlue', '', 'Both;', 8336, 49, '']
# [7024, 7021, 'property', 'PageNamesML', '', '[ENU=Main,Filter,Make; RUS=Общее,Фильтр,Создать] ', 8337, 49, '']
# [7026, 7025, 'property', 'ParentControl', '', '1', 8339, 49, '']
# [7027, 7025, 'property', 'InPage', '', '0;', 8340, 49, '']
# [7028, 7025, 'property', 'SourceExpr', '', '"Recipient No.";', 8341, 49, '']
# [7034, 7033, 'property', 'ParentControl', '', '1000000004', 8348, 49, '']
# [7036, 7035, 'property', 'ParentControl', '', '1', 8349, 49, '']
# [7037, 7035, 'property', 'InPage', '', '0;', 8350, 49, '']
# [7038, 7035, 'property', 'HorzAlign', '', 'Left;', 8351, 49, '']
# [7039, 7035, 'property', 'Lookup', '', 'Yes;', 8352, 49, '']
# [7041, 7035, 'property', 'SourceExpr', '', '"Event No.";', 8355, 49, '']
# [7061, 7060, 'property', 'ParentControl', '', '33', 8381, 49, '']
# [7063, 7062, 'property', 'ParentControl', '', '1', 8382, 49, '']
# [7064, 7062, 'property', 'InPage', '', '0;', 8383, 49, '']
# [7065, 7062, 'property', 'SourceExpr', '', 'Section;', 8384, 49, '']
# [7069, 7068, 'property', 'ParentControl', '', '4', 8389, 49, '']
# [7071, 7070, 'property', 'ParentControl', '', '1', 8390, 49, '']
# [7072, 7070, 'property', 'InPage', '', '0;', 8391, 49, '']
# [7073, 7070, 'property', 'ShowCaption', '', 'No;', 8392, 49, '']
# [7074, 7070, 'property', 'SourceExpr', '', '"Send Comments"', 8393, 49, '']
# [7076, 7075, 'property', 'ParentControl', '', '1000000020', 8394, 49, '']
# [7078, 7077, 'property', 'ParentControl', '', '1', 8395, 49, '']
# [7079, 7077, 'property', 'InPage', '', '0;', 8396, 49, '']
# [7080, 7077, 'property', 'ShowCaption', '', 'No;', 8397, 49, '']
# [7081, 7077, 'property', 'SourceExpr', '', '"Send Attachments"', 8398, 49, '']
# [7083, 7082, 'property', 'ParentControl', '', '1000000022', 8399, 49, '']
# [7085, 7084, 'property', 'ParentControl', '', '1', 8400, 49, '']
# [7086, 7084, 'property', 'InPage', '', '0;', 8401, 49, '']
# [7087, 7084, 'property', 'ShowCaption', '', 'No;', 8402, 49, '']
# [7088, 7084, 'property', 'SourceExpr', '', '"Send Due Info"', 8403, 49, '']
# [7090, 7089, 'property', 'ParentControl', '', '1000000026', 8404, 49, '']
# [7092, 7091, 'property', 'ParentControl', '', '1', 8405, 49, '']
# [7093, 7091, 'property', 'InPage', '', '0;', 8406, 49, '']
# [7094, 7091, 'property', 'ShowCaption', '', 'No;', 8407, 49, '']
# [7095, 7091, 'property', 'SourceExpr', '', '"Send Posting Date"', 8408, 49, '']
# [7097, 7096, 'property', 'ParentControl', '', '1000000040', 8409, 49, '']
# [7099, 7098, 'property', 'ParentControl', '', '1', 8410, 49, '']
# [7100, 7098, 'property', 'InPage', '', '0;', 8411, 49, '']
# [7101, 7098, 'property', 'ShowCaption', '', 'No;', 8412, 49, '']
# [7102, 7098, 'property', 'SourceExpr', '', '"Send Shipment Method Code"', 8413, 49, '']
# ...
# [26919, 26918, 'property', 'DataItemTable', '', 'Table50074;', 29548, 8, '']
# [26920, 26918, 'property', 'DataItemTableView', '', 'SORTING(DF ID,DF Copy,DF Line No);', 29549, 8, '']
# [26926, 26889, 'property', 'FIELDS', '{      ;     ;"DF ID"              }{      ;     ;"DF Copy"           ;OnBeforeEvaluateField=BEGIN{      ;     ;"DF Line No"        ;OnBeforeEvaluateField=BEGIN{      ;     ;"Recipient No"       }{      ;     ;Type                ;OnAfterFormatField=BEGIN{      ;     ;No                   }{      ;     ;Description          }{      ;     ;Quantity            ;OnBeforeEvaluateField=BEGIN{      ;     ;"Unit Price Including VAT";{      ;     ;"Location Type"     ;OnAfterFormatField=BEGIN{      ;     ;"Cargo No"           }{      ;     ;"Source Document No" }{      ;     ;"Quantity to Receive";{      ;     ;"Quantity Defect"   ;OnBeforeEvaluateField=BEGIN{      ;     ;"Entry Type"        ;OnAfterFormatField=BEGIN{      ;     ;"Quantity Non-Liquid";{      ;     ;"Unit Price without VAT";{      ;     ;"Location Code"      }{      ;     ;"Currency Code"      }{      ;     ;Boolean1            ;OnAfterFormatField=BEGIN{      ;     ;Boolean2            ;OnAfterFormatField=BEGIN{      ;     ;Boolean3            ;OnAfterFormatField=BEGIN{      ;     ;Option1             ;OnAfterFormatField=BEGIN{      ;     ;Option2             ;OnAfterFormatField=BEGIN{      ;     ;Option3             ;OnAfterFormatField=BEGIN{      ;     ;Integer1            ;OnBeforeEvaluateField=BEGIN{      ;     ;Integer2            ;OnBeforeEvaluateField=BEGIN{      ;     ;Integer3            ;OnBeforeEvaluateField=BEGIN{      ;     ;Integer4            ;OnBeforeEvaluateField=BEGIN{      ;     ;Integer5            ;OnBeforeEvaluateField=BEGIN{      ;     ;Integer6            ;OnBeforeEvaluateField=BEGIN{      ;     ;Decimal1            ;OnBeforeEvaluateField=BEGIN{      ;     ;Decimal2            ;OnBeforeEvaluateField=BEGIN{      ;     ;Decimal3            ;OnBeforeEvaluateField=BEGIN{      ;     ;Decimal4            ;OnBeforeEvaluateField=BEGIN{      ;     ;Decimal5            ;OnBeforeEvaluateField=BEGIN{      ;     ;Decimal6            ;OnBeforeEvaluateField=BEGIN{      ;     ;Decimal7            ;OnBeforeEvaluateField=BEGIN{      ;     ;Decimal8            ;OnBeforeEvaluateField=BEGIN{      ;     ;Decimal9            ;OnBeforeEvaluateField=BEGIN{      ;     ;Decimal10           ;OnBeforeEvaluateField=BEGIN{      ;     ;Code1                }{      ;     ;Code2                }{      ;     ;Code3                }{      ;     ;Code4                }{      ;     ;Code5                }{      ;     ;Code6                }{      ;     ;Text1                }{      ;     ;Text2                }{      ;     ;Text3                }{      ;     ;Date1                }{      ;     ;Date2                }{      ;     ;Date3                }{      ;     ;Time1                }{      ;     ;Time2                }{      ;     ;Time3                }', ' IF Text = \'\' THEN Text := \'0\' END IF Text = \'\' THEN Text := \'0\' END i:=Type; Text:=FORMAT(i) END IF Text = \'\' THEN Text := \'0\' END OnBeforeEvaluateField=BEGIN IF Text = \'\' THEN Text := \'0\' END i:="Location Type"; Text:=FORMAT(i) END OnBeforeEvaluateField=BEGIN IF Text = \'\' THEN Text := \'0\' END IF Text = \'\' THEN Text := \'0\' END i:="Entry Type"; Text:=FORMAT(i) END OnBeforeEvaluateField=BEGIN IF Text = \'\' THEN Text := \'0\' END OnBeforeEvaluateField=BEGIN IF Text = \'\' THEN Text := \'0\' END IF Boolean1 THEN i:=1 ELSE i:=0; Text:=FORMAT(i) END OnBeforeEvaluateField=BEGIN IF Text = \'1\' THEN Text:=FORMAT(TRUE) ELSE Text:=FORMAT(FALSE) END IF Boolean2 THEN i:=1 ELSE i:=0; Text:=FORMAT(i) END OnBeforeEvaluateField=BEGIN IF Text = \'1\' THEN Text:=FORMAT(TRUE) ELSE Text:=FORMAT(FALSE) END IF Boolean3 THEN i:=1 ELSE i:=0; Text:=FORMAT(i) END OnBeforeEvaluateField=BEGIN IF Text = \'1\' THEN Text:=FORMAT(TRUE) ELSE Text:=FORMAT(FALSE) END i:=Option1; Text:=FORMAT(i) END i:=Option2; Text:=FORMAT(i) END i:=Option3; Text:=FORMAT(i) END IF Text = \'\' THEN Text := \'0\' END IF Text = \'\' THEN Text := \'0\' END IF Text = \'\' THEN Text := \'0\' END IF Text = \'\' THEN Text ...
# [26928, 26927, 'property', 'DataItemTable', '', 'Table50075;', 29735, 8, '']
# [26929, 26927, 'property', 'DataItemTableView', '', 'SORTING(DF ID,DF Copy,Object No);', 29736, 8, '']
# [26935, 26889, 'property', 'FIELDS', '{      ;     ;"DF ID"              }{      ;     ;"DF Copy"           ;OnBeforeEvaluateField=BEGIN{      ;     ;"Object No"         ;OnBeforeEvaluateField=BEGIN{      ;     ;"Object Type"       ;OnAfterFormatField=BEGIN{      ;     ;"Recipient No"       }{      ;     ;Date                 }{      ;     ;Code                 }{      ;     ;Comment              }{      ;     ;"File Name"          }{      ;     ;"Loader ID"          }{      ;     ;"Load Time"          }{      ;     ;Boolean1            ;OnAfterFormatField=BEGIN{      ;     ;Boolean2            ;OnAfterFormatField=BEGIN{      ;     ;Boolean3            ;OnAfterFormatField=BEGIN{      ;     ;Option1             ;OnAfterFormatField=BEGIN{      ;     ;Option2             ;OnAfterFormatField=BEGIN{      ;     ;Option3             ;OnAfterFormatField=BEGIN{      ;     ;Integer1            ;OnBeforeEvaluateField=BEGIN{      ;     ;Integer2            ;OnBeforeEvaluateField=BEGIN{      ;     ;Integer3            ;OnBeforeEvaluateField=BEGIN{      ;     ;Decimal1            ;OnBeforeEvaluateField=BEGIN{      ;     ;Decimal2            ;OnBeforeEvaluateField=BEGIN{      ;     ;Decimal3            ;OnBeforeEvaluateField=BEGIN{      ;     ;Code1                }{      ;     ;Code2                }{      ;     ;Code3                }{      ;     ;Text1                }{      ;     ;Text2                }{      ;     ;Text3                }{      ;     ;Date1                }{      ;     ;Date2                }{      ;     ;Date3                }{      ;     ;Time1                }{      ;     ;Time2                }{      ;     ;Time3                }', ' IF Text = \'\' THEN Text := \'0\' END IF Text = \'\' THEN Text := \'0\' END i:="Object Type"; Text:=FORMAT(i) END IF Boolean1 THEN i:=1 ELSE i:=0; Text:=FORMAT(i) END OnBeforeEvaluateField=BEGIN IF Text = \'1\' THEN Text:=FORMAT(TRUE) ELSE Text:=FORMAT(FALSE) END IF Boolean2 THEN i:=1 ELSE i:=0; Text:=FORMAT(i) END OnBeforeEvaluateField=BEGIN IF Text = \'1\' THEN Text:=FORMAT(TRUE) ELSE Text:=FORMAT(FALSE) END IF Boolean3 THEN i:=1 ELSE i:=0; Text:=FORMAT(i) END OnBeforeEvaluateField=BEGIN IF Text = \'1\' THEN Text:=FORMAT(TRUE) ELSE Text:=FORMAT(FALSE) END i:=Option1; Text:=FORMAT(i) END i:=Option2; Text:=FORMAT(i) END i:=Option3; Text:=FORMAT(i) END IF Text = \'\' THEN Text := \'0\' END IF Text = \'\' THEN Text := \'0\' END IF Text = \'\' THEN Text := \'0\' END IF Text = \'\' THEN Text := \'0\' END IF Text = \'\' THEN Text := \'0\' END IF Text = \'\' THEN Text := \'0\' END', 29745, 6, '']
# [26938, 26937, 'property', 'Width', '', '9020;', 29846, 6, '']
# [26939, 26937, 'property', 'Height', '', '3410;', 29847, 6, '']
# [26955, 26954, 'property', 'Editable', '', 'No', 29867, 51, '']
# [26958, 26954, 'property', 'SourceExpr', '', 'DirectionType', 29872, 51, '']
# [26960, 26959, 'property', 'ParentControl', '', '1000000004', 29873, 51, '']
# [26962, 26961, 'property', 'HorzGlue', '', 'Both', 29874, 51, '']
# [26963, 26961, 'property', 'AssistEdit', '', 'Yes;', 29875, 51, '']
# [26964, 26961, 'property', 'PermanentAssist', '', 'Yes;', 29876, 51, '']
# [26966, 26961, 'property', 'SourceExpr', '', 'FileName', 29879, 51, '']
# [26968, 26967, 'property', 'ParentControl', '', '1', 29880, 51, '']
# [27002, 26999, 'property', 'Modified', '', 'Yes;', 29928, 4, '']
# [27005, 27004, 'property', 'FieldStartDelimiter', '', ';', 29933, 4, '']
# [27006, 27004, 'property', 'FieldEndDelimiter', '', ';', 29934, 4, '']
# [27007, 27004, 'property', 'FieldSeparator', '', '<TAB>;', 29935, 4, '']
# [27010, 27009, 'property', 'DataItemTable', '', 'Table50072;', 29941, 8, '']
# [27011, 27008, 'property', 'FIELDS', '{      ;     ;"No."               ;OnBeforeEvaluateField=BEGIN{      ;     ;"Partner No."        }{      ;     ;Section             ;OnAfterFormatField=BEGIN{      ;     ;"Event No."         ;OnBeforeEvaluateField=BEGIN{      ;     ;"DF Document Type"  ;OnAfterFormatField=BEGIN{      ;     ;"Recipient No."      }{      ;     ;"Enable Rule"       ;OnAfterFormatField=BEGIN{      ;     ;Description          }{      ;     ;"Make from"         ;OnAfterFormatField=BEGIN{      ;     ;"Customer No."       }{      ;     ;"Vendor No."         }{      ;     ;"Document Type"     ;OnAfterFormatField=BEGIN{      ;     ;"Document SubType"  ;OnAfterFormatField=BEGIN{      ;     ;"Location Code"      }{      ;     ;"Bin Code"           }{      ;     ;"New Location Code"  }{      ;     ;"New Bin Code"       }{      ;     ;"DF Correction"     ;OnAfterFormatField=BEGIN{      ;     ;"DF Import Type"    ;OnAfterFormatField=BEGIN{      ;     ;"DF Export Type"    ;OnAfterFormatField=BEGIN{      ;     ;"Location Type"     ;OnAfterFormatField=BEGIN{      ;     ;"New Location Type" ;OnAfterFormatField=BEGIN{      ;     ;"Sign Level"        ;OnAfterFormatField=BEGIN{      ;     ;"In-Transit Code"    }{      ;     ;"To Section"        ;OnAfterFormatField=BEGIN{      ;     ;"To DF Document Type";{      ;     ;"To Document Type Custom";{      ;     ;"To Document SubType Custom";{      ;     ;"Make from Division No." }{      ;     ;"To Location Type Variant";{      ;     ;"To Location Type Custom";{      ;     ;"To Location Code"   }{      ;     ;"To Bin Code"        }{      ;     ;"To New Location Code" }{      ;     ;"To New Bin Code"    }{      ;     ;"To In-Transit Code" }{      ;     ;"To Source Table No.";{      ;     ;"To Reason Code"     }{      ;     ;"To Posting Date Source";{      ;     ;"Original Numeration";{      ;     ;"Send Comments"     ;OnAfterFormatField=BEGIN{      ;     ;"Send Attachments"  ;OnAfterFormatField=BEGIN{      ;     ;"Send Due Info"     ;OnAfterFormatField=BEGIN{      ;     ;"Send Posting Date" ;OnAfterFormatField=BEGIN{      ;     ;"Send Shipment Method Code";{      ;     ;"Send GTD"          ;OnAfterFormatField=BEGIN{      ;     ;"To New Location Type Variant";{      ;     ;"To Department Code" }{      ;     ;"Send Сounteragent Code";{      ;     ;"Functionality Filter";{      ;     ;"To Functionality Variant";{      ;     ;"To Functionality Custom";{      ;     ;"Last Modified UserID" }{      ;     ;"Last Modified Date" }{      ;     ;"Last Modified Time" }{      ;     ;"Business Type Filter";{      ;     ;"Export Transform"  ;OnAfterFormatField=BEGIN{      ;     ;"Send Planing Shipment Date";{      ;     ;"Send Shipment Time Code";{      ;     ;"Send Packing Type" ;OnAfterFormatField=BEGIN{      ;     ;"Auto-Action"       ;OnAfterFormatField=BEGIN{      ;     ;"Post Parameters"    }{      ;     ;"Balance Document"  ;OnAfterFormatField=BEGIN', ' IF Text = \'\' THEN Text := \'0\' END i:=Section; Text:=FORMAT(i) END IF Text = \'\' THEN Text := \'0\' END i:="DF Document Type"; Text:=FORMAT(i) END OnBeforeEvaluateField=BEGIN IF EVALUATE(i,Text) THEN BEGIN "DF Document Type":=i Text := FORMAT("DF Document Type") END END IF "Enable Rule" THEN i:=1 ELSE i:=0; Text:=FORMAT(i) END OnBeforeEvaluateField=BEGIN IF Text = \'1\' THEN Text:=FORMAT(TRUE) ELSE Text:=FORMAT(FALSE) END i:="Make from"; Text:=FORMAT(i) END i:="Document Type"; Text:=FORMAT(i) END OnBeforeEvaluateField=BEGIN IF EVALUATE(i,Text) THEN BEGIN "Document Type":=i Text := FORMAT("Document Type") END END i:="Document SubType"; Text:=FORMAT(i) END OnBeforeEvaluateField=BEGIN IF EVALUATE(i,Text) THEN BEGIN "Document SubType":=i Text := FORMAT("Document SubType") END END i:="DF Correction"; Text:=FORMAT(i) END i:="DF Import Type"; Text:=FORMAT(i) END i:="DF Export Type"; Text:=FORMAT(i) END i:="Location Type"; Text:=FORMAT(i) END i:="New Location Type"; Text:=FORMAT(i) END i:="Sign Level"; Text:=FORMAT(i) END i:="To Section"; Text:=FOR ...
# [27023, 27020, 'property', 'Modified', '', 'Yes;', 30284, 4, '']
# [27026, 27025, 'property', 'Permissions', '', 'TableData 112=m, TableData 114=m, TableData 122=m, TableData 124=m, TableData 50070=r, TableData 50071=rm, TableData 50072=r, TableData 50073=rimd, TableData 50074=rimd, TableData 50075=rimd, TableData 50076=rimd', 30289, 4, '']
# [29867, 29866, 'property', 'TableNo', '', '50072;', 33521, 4, '']
# [30105, 30102, 'property', 'Modified', '', 'Yes;', 33782, 4, '']
# [30108, 30107, 'property', 'TableNo', '', '50073;', 33787, 4, '']
# [34742, 34739, 'property', 'Modified', '', 'Yes;', 39094, 4, '']
# [34745, 34744, 'property', 'TableNo', '', '50073;', 39099, 4, '']
# [34746, 34744, 'property', 'Permissions', '', 'TableData 50073=rimd, TableData 50074=rimd, TableData 50075=rimd, TableData 50076=rimd', 39100, 4, '']
# [36675, 36672, 'property', 'Modified', '', 'Yes;', 41300, 4, '']
# [36678, 36677, 'property', 'TableNo', '', '50073;', 41305, 4, '']
# [36679, 36677, 'property', 'Permissions', '', 'TableData 50073=rimd, TableData 50074=rimd, TableData 50075=rimd, TableData 50076=rimd', 41306, 4, '']
# [40237, 40236, 'property', 'TableNo', '', '50073;', 45301, 4, '']
# [40238, 40236, 'property', 'Permissions', '', 'TableData 50073=rimd, TableData 50074=rimd, TableData 50075=rimd, TableData 50076=rimd', 45302, 4, '']
# [40855, 40854, 'property', 'TableNo', '', '50073;', 46008, 4, '']
# [40856, 40854, 'property', 'Permissions', '', 'TableData 12451=m, TableData 50073=rimd, TableData 50074=rimd, TableData 50075=rimd, TableData 50076=rimd', 46009, 4, '']
# [41605, 41602, 'property', 'Modified', '', 'Yes;', 46848, 4, '']
# [41608, 41607, 'property', 'TableNo', '', '50073;', 46853, 4, '']
# [41609, 41607, 'property', 'Permissions', '', 'TableData 7322=m, TableData 12451=m, TableData 50073=rimd, TableData 50074=rimd, TableData 50075=rimd, TableData 50076=rimd', 46854, 4, '']
# [51125, 51122, 'property', 'Modified', '', 'Yes;', 57596, 4, '']
# [56827, 54966, 'property', 'EVENT OutlNameSpace@1000000045::OptionsPagesAdd@61445(Pages@1000000001', 'Automation', 'Unknown Automation Server.PropertyPages";Folder@1000000000 : Automation "{00062FFF-0000-0000-C000-000000000046} 9.2:{00063006-0000-0000-C000-000000000046}:Unknown Automation Server.MAPIFolder");', 64299, 4, '']
# [56916, 56913, 'property', 'Modified', '', 'Yes;', 64424, 4, '']
# [65128, 65125, 'property', 'Modified', '', 'Yes;', 74002, 4, '']
# [65131, 65130, 'property', 'TableNo', '', '55012;', 74007, 4, '']
# [65250, 65247, 'property', 'Modified', '', 'Yes;', 74152, 4, '']
# [66187, 65255, 'property', 'EVENT xlApplication@1000000000::NewWorkbook@1565(Wb@1000000000', 'Automation', 'Unknown Automation Server.Workbook");', 75198, 4, '']
# [66346, 66343, 'property', 'Modified', '', 'Yes;', 75412, 4, '']
# [67140, 67137, 'property', 'Modified', '', 'Yes;', 76342, 4, '']
# [67143, 67142, 'property', 'SingleInstance', '', 'Yes;', 76347, 4, '']
# [67275, 67272, 'property', 'Modified', '', 'Yes;', 76519, 4, '']

# %%
import pandas as pd
dt = pd.DataFrame(propTable)

# %%
dt[2].unique()
# Out:
# array(['root', 'object', 'section', 'property', 'field', 'trigger', 'cal',
#        'var', 'key', 'procedure', 'param', 'documentation', 'control'],
#       dtype=object)

# %%
ls = propTable[0:6]
ls
# Out:
# [[0, 0, 'root', 'objName', 'objType', 'objNo', 'lineNo', 0],
#  [1, 0, 'object', 'DocFlow Setup', 'Table', '50071', 1, 0],
#  [2, 1, 'section', 'OBJECT-PROPERTIES', '', '', 3, 2],
#  [3, 2, 'property', 'Date', '', '12.09.21;', 5, 4, ''],
#  [4, 2, 'property', 'Time', '', '13:58:19;', 6, 4, ''],
#  [5, 2, 'property', 'Modified', '', 'Yes;', 7, 4, '']]

# %%
#ls.remove([4, 2, 'property', 'Time', '', '13:58:19;', 6, 4,''])
#ls.insert(1, 'ins')
#res = ls.index([3, 2, 'property', 'Date', '', '12.09.21;', 5, 4, ''])  #ls.index('abc') error
#res #3
ls2 = sorted(ls)
ls2
# Out:
# [[0, 0, 'root', 'objName', 'objType', 'objNo', 'lineNo', 0],
#  [1, 0, 'object', 'DocFlow Setup', 'Table', '50071', 1, 0],
#  [2, 1, 'section', 'OBJECT-PROPERTIES', '', '', 3, 2],
#  [3, 2, 'property', 'Date', '', '12.09.21;', 5, 4, ''],
#  [4, 2, 'property', 'Time', '', '13:58:19;', 6, 4, ''],
#  [5, 2, 'property', 'Modified', '', 'Yes;', 7, 4, '']]

# %%
propTable.typeof()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[96], line 1
# ----> 1 propTable.typeof()
#
# AttributeError: 'list' object has no attribute 'typeof'
